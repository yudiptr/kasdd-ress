# %% [markdown]
# <center>
# <img src="https://drive.google.com/uc?id=1f1gGVI-rxcHjA90WEGNvvtSXF1pAxQwg" alt="Fasilkom UI" width="300"/>
#
# CSGE603130 • Kecerdasan Artifisial dan Sains Data Dasar
#
# Semester Ganjil 2022/2023
#
# Fakultas Ilmu Komputer, Universitas Indonesia
#
# ##*Lab 4*: CART
#
# ###**Tenggat Waktu: 8 Oktober 2023, 23.55 WIB**
# </center>
#
# ####**Ketentuan:**
#
# 1. Dokumen *template* lab dengan format .ipynb dan dataset (jika dibutuhkan) telah disediakan di SCeLe
# 2. Jalankan kode pada dokumen .ipynb dan perhatikan dengan saksama apa yang potongan kode tersebut lakukan beserta dengan keluarannya. Jawablah **pertanyaan yang disisipkan** pada potongan program yang diberikan.
# 3. Dokumen Jupyter Notebook yang telah dilengkapi dengan jawaban dikumpulkan dengan format penamaan **Kelas_LabX_NPM_Nama.ipynb**. Contoh: A_Lab4_2006123456_Budi.ipynb
# 4. Kumpulkan dokumen tersebut pada submisi yang telah disediakan di SCeLe sesuai dengan kelas masing-masing sebelum **8 Oktober 2023, 23.55 WIB**. Keterlambatan pengumpulan akan dikenakan pinalti.
# 5. Lab ini dirancang sebagai **tugas mandiri**. Plagiarisme tidak diperkenankan dalam bentuk apapun. Adapun kolaborasi berupa diskusi (tanpa menyalin maupun mengambil jawaban orang lain) dan literasi masih diperbolehkan dengan mencantumkan kolaborator dan sumber.

# %% [markdown]
# ## **Pernyataan Integritas**
#
# Wajib diisi. Tanpa pernyataan integritas submisi akan dikenakan pinalti.

# %%
# Isi dengan data diri Anda
NAMA = "Yudi Putra Sabri"
NAMA_TEAM_KAGGLE = "YudiSabri"
KELAS = "D"
NPM = "2106706123"

# Isi dengan NPM teman yang berdiskusi dengan Anda
KOLABORATOR = []

# Isi dengan sumber referensi yang Anda gunakan dalam mengerjakan
REFERENSI = []

# %%
PERNYATAAN_INTEGRITAS = "Saya, %s dari kelas %s dengan NPM %s, menyatakan bahwa seluruh jawaban pada pekerjaan ini murni saya kerjakan sendiri.\n\
Saya tidak mencontek jawaban, memberikan jawaban, maupun menyalin dari sumber manapun.\n \
\n\
Jika saya melanggar pernyataan tersebut, saya siap menerima konsekuensi apapun yang diberikan.\n   \
(%s)\n     \
(%s)" % (NAMA, KELAS, NPM, NAMA, NAMA_TEAM_KAGGLE)

print(PERNYATAAN_INTEGRITAS)
# Out:
# Saya, Yudi Putra Sabri dari kelas D dengan NPM 2106706123, menyatakan bahwa seluruh jawaban pada pekerjaan ini murni saya kerjakan sendiri.
# Saya tidak mencontek jawaban, memberikan jawaban, maupun menyalin dari sumber manapun.
#
# Jika saya melanggar pernyataan tersebut, saya siap menerima konsekuensi apapun yang diberikan.
#    (Yudi Putra Sabri)
#      (YudiSabri)

# %% [markdown]
# ## Deskripsi Dataset

# %% [markdown]
# Lab ini akan menggunakan 2 dataset, yakni dataset untuk klasifikasi dan dataset untuk regresi.
#
# Dataset yang digunakan untuk klasifikasi adalah dataset **Red Wine Quality** (https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009) dengan modifikasi.
#
# Dataset yang akan digunakan untuk regresi adalah dataset **Graduate Admission 2** (https://www.kaggle.com/datasets/mohansacharya/graduate-admissions) dengan modifikasi.

# %% [markdown]
# ### Deskripsi Dataset Klasifikasi

# %% [markdown]
# Dataset ini berisi informasi mengenai atribut-atribut yang dirasa berpengaruh terhadap kualitas dari suatu Red Wine yang diukur dengan angka 0 sampai dengan 10 (Quality).
#
# Atribut-atribut yang terdapat pada dataset ini adalah sebagai berikut:
#
#
# *   **Fixed Acidity**: Sebagian besar asam yang terlibat dalam anggur adalah asam tetap atau tidak mudah menguap (tidak menguap dengan mudah).
# *   **Volatile Acidity**: Jumlah asam asetat dalam anggur, yang pada kadar yang terlalu tinggi dapat menyebabkan rasa cuka yang tidak enak.
# *   **Citric Acid**: Ditemukan dalam jumlah kecil, asam sitrat dapat menambahkan 'kesegaran' dan rasa pada anggur.
# *   **Residual Sugar**: Jumlah gula yang tersisa setelah fermentasi berhenti.
# *   **Chlorides**: Jumlah kadar garam pada wine.
# *   **Free Sulfur Dioxide**: Bentuk bebas SO2 ada dalam keseimbangan antara SO2 molekuler (sebagai gas terlarut) dan ion bisulfit.
# *   **Total Sulfur Dioxide**: Jumlah bentuk bebas dan terikat dari SO2.
# *   **Density**: Kepadatan air tergantung pada persentase alkohol dan kandungan gula.
# *   **pH**: Menggambarkan seberapa asam atau basa suatu anggur pada skala dari 0 (sangat asam) hingga 14 (sangat basa).
# *   **Sulphates**: Sebuah tambahan untuk anggur yang dapat berkontribusi pada tingkat gas sulfur dioksida (SO2).
# *   **Alcohol**: Persentase kandungan alkohol dalam anggur.
# *   **Quality**: Variabel keluaran (berdasarkan data sensori, skor antara 0 dan 10).

# %% [markdown]
# ### Deskripsi Dataset Regresi

# %% [markdown]
# Dataset ini berisi informasi mengenai atribut-atribut yang dirasa berpengaruh terhadap besarnya peluang (Chance of Admit) dari seorang pelamar untuk diterima pada program Magister-nya di daerah India.
#
# Atribut-atribut yang terdapat pada dataset ini adalah sebagai berikut:
#
#
#
# *   **GRE Scores (out of 340)**: Skor yang diperoleh oleh calon pelamar pada tes GRE.
# *   **TOEFL Scores (out of 120)**: Skor yang diperoleh oleh calon pelamar pada tes TOEFL.
# *   **University Rating (out of 5)**: Rating universitas yang didaftar oleh calon pelamar.
# *  **Statement of Purpose and Letter of Recommendation Strength (out of 5)**: Skor yang diperoleh dari surat rekomendasi yang dilampirkan oleh calon pelamar.
# *   **Undergraduate GPA (out of 10)**: GPA yang diperoleh oleh calon pelamar pada saat masa *undergraduate*.
# *   **Research Experience (either 0 or 1)**: Ada/tidaknya pengalaman meneliti yang dimiliki oleh calon pelamar. 0 berarti tidak, 1 berarti iya.
# *   **Chance of Admit (ranging from 0 to 1)**: Peluang diterimanya calon pelamar pada suatu universitas dengan skor-skor yang dimilikinya.

# %% [markdown]
# ## Import Libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import tree
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Read Datasets

# %% [markdown]
# **Bacalah konten dari masing-masing dataset yang telah disediakan. Perhatikan tipe data dari masing-masing kolom, apakah sudah cocok untuk dijadikan input ke dalam model atau tidak.**

# %% [markdown]
# ### Dataset Red Wine

# %% [markdown]
# **Terapkan proses Read Dataset di bawah cell ini**

# %%
df = pd.read_csv("Red_Wine_Quality_Train.csv")

# %% [markdown]
# ### Dataset Admission Prediction

# %%
df2 = pd.read_csv('Admission_Prediction_Train.csv')

# %% [markdown]
# ## SOAL 1 Data Pre-processing [20]

# %% [markdown]
# **Terapkanlah proses data pre-processing pada bagian ini agar dataset yang telah diberikan dapat dijadikan input dari model yang akan kalian buat. Terapkan proses tersebut untuk masing-masing dataset (Red Wine & Admission Prediction) hingga dataset terbagi menjadi train dan test**

# %% [markdown]
# ### Dataset Red Wine

# %% [markdown]
# **Terapkan proses data pre-processing di bawah cell ini**

# %%
#drop duplicate untuk mengurangi rebundant
df = df.drop_duplicates()
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         12.200000          0.450000     0.490000        1.400000   0.075000
# 1          7.100000          0.430000     0.170000        1.800000   0.082000
# 2          7.784053          0.280000     0.303572        1.993696   0.061832
# 3          7.960832          0.762917     0.015375        2.490418   0.085412
# 4          7.700000          0.705000     0.100000        2.600000   0.084000
# ...             ...               ...          ...             ...        ...
# 3459       7.739080          0.747077     0.029631        2.759688   0.082086
# 3460       6.794068          0.811737     0.001186        1.235593   0.255788
# 3461       8.285252          1.017603     0.020000        3.385252   0.083945
# 3463       7.873784          0.350633     0.458011        3.585536   0.077837
# 3465       5.787771          0.925706     0.078195        1.423872   0.053355
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0                3.000000              6.000000  0.996900  3.130000
# 1               27.000000             51.000000  0.996340  3.490000
# 2               17.978987             33.957974  0.995235  3.277268
# 3               13.341669             26.512503  0.997363  3.376833
# 4                9.000000             26.000000  0.997600  3.390000
# ...                   ...                   ...       ...       ...
# 3459            13.658457             26.987685  0.996957  3.383169
# 3460            15.406785             27.991534  0.994787  3.333644
# 3461             6.000000             11.009217  0.998893  3.480645
# 3463            15.036160             37.117519  0.997249  3.353345
# 3465            37.657942             93.116426  0.994612  3.609156
#
#       sulphates    alcohol  quality
# 0      0.630000  10.400000        5
# 1      0.640000  10.400000        5
# 2      0.895167  11.285291        7
# 3      0.470250   9.856252        4
# 4      0.490000   9.700000        5
# ...         ...        ...      ...
# 3459   0.479754  10.093843        4
# 3460   0.517119   9.808898        3
# 3461   0.491290  10.990322        3
# 3463   0.858915  12.810848        8
# 3465   0.632780  10.165794        4
#
# [3224 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3224 entries, 0 to 3465
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         3224 non-null   float64
#  1   volatile acidity      3224 non-null   float64
#  2   citric acid           3224 non-null   float64
#  3   residual sugar        3224 non-null   float64
#  4   chlorides             3224 non-null   float64
#  5   free sulfur dioxide   3224 non-null   float64
#  6   total sulfur dioxide  3224 non-null   float64
#  7   density               3224 non-null   float64
#  8   pH                    3224 non-null   float64
#  9   sulphates             3224 non-null   float64
#  10  alcohol               3224 non-null   float64
#  11  quality               3224 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 327.4 KB

# %%
# cek null untuk diisi dengan mean/median/modus
print(df.isnull().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# cek hubungan antar fitur untuk melakukan drop column untuk fitur yang sangat tidak berhubungan
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
# memisahkan nilai y dan x
df_raw = df.drop("quality", axis=1)
df_target = df['quality']

# %%
X_train_red, X_test_red, y_train_red, y_test_red = train_test_split(df_raw, df_target, test_size=0.2)

# %% [markdown]
# ### Dataset Admission Prediction

# %% [markdown]
# **Terapkan proses data pre-processing di bawah cell ini**

# %%
df2 = df2.drop_duplicates()
df2
# Out:
#      Unnamed: 0  Serial No.  GRE Score  TOEFL Score  University Rating  SOP  \
# 0             5           6        330          115                  5  4.5
# 1           116         117        299          102                  3  4.0
# 2            45          46        322          110                  5  5.0
# 3            16          17        317          107                  3  4.0
# 4           462         463        307          105                  4  3.0
# ..          ...         ...        ...          ...                ...  ...
# 345         106         107        329          111                  4  4.5
# 346         270         271        306          105                  2  2.5
# 347         348         349        302           99                  1  2.0
# 348         435         436        309          105                  2  2.5
# 349         102         103        314          106                  2  4.0
#
#      LOR   CGPA  Research  Chance of Admit
# 0     3.0  9.34         1             0.90
# 1     3.5  8.62         0             0.56
# 2     4.0  9.10         1             0.88
# 3     3.0  8.70         0             0.66
# 4     3.0  7.94         0             0.62
# ..    ...   ...       ...              ...
# 345   4.5  9.18         1             0.87
# 346   3.0  8.22         1             0.72
# 347   2.0  7.25         0             0.57
# 348   4.0  7.68         0             0.55
# 349   3.5  8.25         0             0.62
#
# [350 rows x 10 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         350 non-null    int64
#  1   Serial No.         350 non-null    int64
#  2   GRE Score          350 non-null    int64
#  3   TOEFL Score        350 non-null    int64
#  4   University Rating  350 non-null    int64
#  5   SOP                350 non-null    float64
#  6   LOR                350 non-null    float64
#  7   CGPA               350 non-null    float64
#  8   Research           350 non-null    int64
#  9   Chance of Admit    350 non-null    float64
# dtypes: float64(4), int64(6)
# memory usage: 27.5 KB

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0           0
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
sns.heatmap(df2.corr(),annot=True)
# Out:
# <Axes: >

# %%
# Karena fitur Unnamed: 0 dan Serial No. sangat tidak berhubungan dengan fitur lainnya, dapat didrop
df2.drop(columns=["Serial No." ,"Unnamed: 0"], inplace=True)
sns.heatmap(df2.corr(),annot=True)
# Out:
# <Axes: >

# %%
df2_raw = df2.drop("Chance of Admit", axis=1)
df2_target = df2['Chance of Admit']

# %%
X_train_admission, X_test_admission, y_train_admission, y_test_admission = train_test_split(df2_raw, df2_target, test_size=0.2)

# %% [markdown]
# ## CART (Classification and Regression Tree)

# %% [markdown]
# ### Decision Tree
#
# Decision Tree merupakan model yang beroperasi dengan struktur berbentuk Binary Tree, di mana setiap node hanya dapat memiliki dua child node paling banyak. Dalam bidang data science, model ini diterapkan dalam konteks Supervised Learning, yaitu model dibentuk berdasarkan data training dan selanjutnya digunakan untuk membuat prediksi terhadap data yang disajikan. Data training yang digunakan akan diolah menjadi sebuah rangkaian aturan dalam bentuk Binary Tree. Aturan-aturan ini selanjutnya digunakan untuk proses prediksi pada dataset lain.

# %% [markdown]
# #### Training

# %% [markdown]
# Function di bawah ini merupakan function yang dapat digunakan untuk menghitung metrics hasil testing, baik untuk kasus regresi, maupun kasus klasifikasi.

# %%
# https://medium.com/analytics-vidhya/evaluation-metrics-for-regression-models-c91c65d73af
def regression_metrics(prediction, y_test):
    MAE = mean_absolute_error(y_test, prediction)
    MSE = mean_squared_error(y_test, prediction)
    RMSE = np.sqrt(MSE)
    R_squared = r2_score(y_test, prediction)

    print('MAE: ' + str(MAE))
    print('MSE: ' + str(MSE))
    print('RMSE: ' + str(RMSE))
    print('R_squared: ' + str(R_squared))

# %%
def classification_metrics(prediction, y_test):
  accuracy = accuracy_score(y_test, prediction)
  f1 = f1_score(y_test, prediction, average="macro")
  recall = recall_score(y_test, prediction, average="macro")
  precision = precision_score(y_test, prediction, average="macro")

  print('Accuracy: ' + str(accuracy))
  print('F1 Score: ' + str(f1))
  print('Recall Score: ' + str(recall))
  print('Precision Score: ' + str(precision))

# %% [markdown]
# ##### Dataset Red Wine

# %%
# Melakukan training pada model decision tree
# Sesuaikan nama variable X_train dan y_train kamu
dtc_red = DecisionTreeClassifier(max_depth=3, random_state=42)
dtc_red.fit(X_train_red, y_train_red)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %% [markdown]
# ##### Dataset Admission Prediction

# %%
# Melakukan training pada model decision tree
# Sesuaikan nama variable X_train dan y_train kamu
dtr_admission = DecisionTreeRegressor(max_depth=3, random_state=42)
dtr_admission.fit(X_train_admission, y_train_admission)
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=42)

# %% [markdown]
# #### Evaluation

# %% [markdown]
# ##### Dataset Red Wine

# %%
# Memprediksi data testing
prediction = dtc_red.predict(X_test_red)

# Call the metrics function
classification_metrics(prediction, y_test_red)
# Out:
# Accuracy: 0.49612403100775193
# F1 Score: 0.4314583134361773
# Recall Score: 0.4896974003966384
# Precision Score: 0.4403459498141001
# c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ##### Dataset Admission Prediction

# %%
# Memprediksi data testing
prediction = dtr_admission.predict(X_test_admission)

# Call the metrics function
regression_metrics(prediction, y_test_admission)
# Out:
# MAE: 0.05517248994739595
# MSE: 0.005377498352837944
# RMSE: 0.0733314281385406
# R_squared: 0.7295243078535627

# %% [markdown]
# #### Hyperparameter

# %% [markdown]
# Hyperparameter adalah parameter yang dapat kita sesuaikan atau konfigurasi sebelum memulai proses pembangunan model. Tujuan dari penyesuaian ini adalah untuk mengoptimalisasi performa model sehingga diharapkan dapat berfungsi lebih efektif.
#
# > Ada beberapa jenis hyperparameter yang terdapat dalam beragam algoritma machine learning, termasuk dalam algoritma Decision Tree. Beberapa hyperparameter yang ada dalam algoritma Decision Tree yang disediakan oleh modul sklearn.tree antara lain:
#
# - `criterion`: Metrik yang digunakan untuk mengevaluasi kualitas pemisahan node, contohnya:
# - `squared_error`: menggunakan reduksi varians sebagai kriteria seleksi fitur dan meminimalkan kerugian L2 dengan menggunakan mean dari setiap node terminal
# - `friedman_mse`: menghitung mean squared error dengan Friedman's improvement score untuk kemungkinan pemisahan (tidak perlu khawatir, ini tidak akan keluar di ujian)
# - `absolute_error`: meminimalkan kerugian L1 dengan menggunakan median dari setiap node terminal
# - `poisson`: memanfaatkan reduksi dalam Poisson deviance untuk menentukan pemisahan
# - `max_depth`: Membatasi kedalaman maksimum dari pohon
# - `min_samples_split`: Menentukan jumlah minimum sampel yang dibutuhkan untuk memecah sebuah node internal
# Untuk informasi lebih detail, Anda bisa merujuk pada dokumentasi berikut:
# [sklearn decision tree](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html)

# %%
# Melakukan training pada model decision tree
# Decision tree yang dibangun memiliki hyperparameter max_depth=3
dtr_md6 = DecisionTreeRegressor(max_depth=6, random_state=42)
dtr_md6.fit(X_train_admission, y_train_admission)

# Memprediksi data testing
predicted6 = dtr_md6.predict(X_test_admission)

# Menampilkan metrics evaluasi
regression_metrics(predicted6, y_test_admission)
# Out:
# MAE: 0.05707999203177775
# MSE: 0.005807662696870324
# RMSE: 0.07620802252302787
# R_squared: 0.707888039266428

# %% [markdown]
# Perubahan *hyperparameter* dapat mempengaruhi performa dari model. Pada awalnya dengan `max_depth = 3` model menghasilkan *MAE* 0.04837917276086966 dan *RMSE* 0.06888923287937174. Setelah dilakukan perubahan *hyperparameter* dengan `max_depth = 6`, kita dapat melihat bahwa ada penurunan pada performa model dengan *MAE* 0.049144375215427846 dan *RMSE* 0.0704508435958617
#
# Bagaimana jika hyperparameter lain diubah? Silakan eksplorasi perubahan hyperparameter lain secara mandiri ya!😃

# %% [markdown]
# ### Visualisasi Decision Tree yang Dihasilkan

# %% [markdown]
# Kita bisa melakukan visualisasi terhadap serangkaian aturan yang membentuk Decision Tree yang telah dibangun. Salah satu caranya adalah dengan menggunakan modul `sklearn.tree.plot_tree` dengan bantuan `matplotlib`.
#
# Berikut adalah contoh visualisasi decision tree pada dataset Admission Prediction tanpa max depth:

# %%
# Membangun model tree
tree_model = DecisionTreeRegressor()
tree_model.fit(X_train_admission, y_train_admission)

# Melakukan visualisasi pada decision tree yang sudah dibangun sebelumnya
print(tree.export_text(tree_model, feature_names=pd.Series(X_train_admission.columns).array))
# Out:
# |--- CGPA <= 8.75
# |   |--- CGPA <= 8.22
# |   |   |--- TOEFL Score <= 101.50
# |   |   |   |--- CGPA <= 7.66
# |   |   |   |   |--- GRE Score <= 307.00
# |   |   |   |   |   |--- CGPA <= 7.65
# |   |   |   |   |   |   |--- CGPA <= 7.03
# |   |   |   |   |   |   |   |--- value: [0.36]
# |   |   |   |   |   |   |--- CGPA >  7.03
# |   |   |   |   |   |   |   |--- CGPA <= 7.64
# |   |   |   |   |   |   |   |   |--- CGPA <= 7.27
# |   |   |   |   |   |   |   |   |   |--- value: [0.57]
# |   |   |   |   |   |   |   |   |--- CGPA >  7.27
# |   |   |   |   |   |   |   |   |   |--- SOP <= 1.75
# |   |   |   |   |   |   |   |   |   |   |--- LOR  <= 2.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- LOR  >  2.75
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.53]
# |   |   |   |   |   |   |   |   |   |--- SOP >  1.75
# |   |   |   |   |   |   |   |   |   |   |--- SOP <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- SOP >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.47]
# |   |   |   |   |   |   |   |--- CGPA >  7.64
# |   |   |   |   |   |   |   |   |--- value: [0.57]
# |   |   |   |   |   |--- CGPA >  7.65
# |   |   |   |   |   |   |--- value: [0.38]
# |   |   |   |   |--- GRE Score >  307.00
# |   |   |   |   |   |--- LOR  <= 2.25
# |   |   |   |   |   |   |--- CGPA <= 7.37
# |   |   |   |   |   |   |   |--- value: [0.54]
# |   |   |   |   |   |   |--- CGPA >  7.37
# |   |   |   |   |   |   |   |--- value: [0.49]
# |   |   |   |   |   |--- LOR  >  2.25
# |   |   |   |   |   |   |--- CGPA <= 7.55
# |   |   |   |   |   |   |   |--- value: [0.57]
# |   |   |   |   |   |   |--- CGPA >  7.55
# |   |   |   |   |   |   |   |--- value: [0.62]
# |   |   |   |--- CGPA >  7.66
# |   |   |   |   |--- SOP <= 3.75
# |   |   |   |   |   |--- CGPA <= 8.01
# |   |   |   |   |   |   |--- GRE Score <= 297.50
# |   |   |   |   |   |   |   |--- CGPA <= 7.77
# |   |   |   |   |   |   |   |   |--- CGPA <= 7.67
# |   |   |   |   |   |   |   |   |   |--- value: [0.59]
# |   |   |   |   |   |   |   |   |--- CGPA >  7.67
# |   |   |   |   |   |   |   |   |   |--- value: [0.60]
# |   |   |   |   |   |   |   |--- CGPA >  7.77
# |   |   |   |   |   |   |   |   |--- value: [0.69]
# |   |   |   |   |   |   |--- GRE Score >  297.50
# |   |   |   |   |   |   |   |--- University Rating <= 3.50
# |   |   |   |   |   |   |   |   |--- TOEFL Score <= 100.50
# |   |   |   |   |   |   |   |   |   |--- SOP <= 2.75
# |   |   |   |   |   |   |   |   |   |   |--- CGPA <= 7.88
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.51]
# |   |   |   |   |   |   |   |   |   |   |--- CGPA >  7.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- SOP >  2.75
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.48]
# |   |   |   |   |   |   |   |   |--- TOEFL Score >  100.50
# |   |   |   |   |   |   |   |   |   |--- CGPA <= 7.95
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.49]
# |   |   |   |   |   |   |   |   |   |--- CGPA >  7.95
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.46]
# |   |   |   |   |   |   |   |--- University Rating >  3.50
# |   |   |   |   |   |   |   |   |--- LOR  <= 3.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.42]
# |   |   |   |   |   |   |   |   |--- LOR  >  3.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.53]
# |   |   |   |   |   |--- CGPA >  8.01
# |   |   |   |   |   |   |--- GRE Score <= 306.50
# |   |   |   |   |   |   |   |--- LOR  <= 2.75
# |   |   |   |   |   |   |   |   |--- CGPA <= 8.03
# |   |   |   |   |   |   |   |   |   |--- value: [0.63]
# |   |   |   |   |   |   |   |   |--- CGPA >  8.03
# |   |   |   |   |   |   |   |   |   |--- CGPA <= 8.12
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.61]
# |   |   |   |   |   |   |   |   |   |--- CGPA >  8.12
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.62]
# |   |   |   |   |   |   |   |--- LOR  >  2.75
# |   |   |   |   |   |   |   |   |--- GRE Score <= 302.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.67]
# |   |   |   |   |   |   |   |   |--- GRE Score >  302.50
# |   |   |   |   |   |   |   |   |   |--- CGPA <= 8.14
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.64]
# |   |   |   |   |   |   |   |   |   |--- CGPA >  8.14
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.63]
# |   |   |   |   |   |   |--- GRE Score >  306.50
# |   |   |   |   |   |   |   |--- GRE Score <= 310.50
# |   |   |   |   |   |   |   |   |--- value: [0.48]
# |   |   |   |   |   |   |   |--- GRE Score >  310.50
# |   |   |   |   |   |   |   |   |--- LOR  <= 2.25
# |   |   |   |   |   |   |   |   |   |--- value: [0.56]
# |   |   |   |   |   |   |   |   |--- LOR  >  2.25
# |   |   |   |   |   |   |   |   |   |--- Research <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.62]
# |   |   |   |   |   |   |   |   |   |--- Research >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.64]
# |   |   |   |   |--- SOP >  3.75
# |   |   |   |   |   |--- CGPA <= 8.11
# |   |   |   |   |   |   |--- value: [0.34]
# |   |   |   |   |   |--- CGPA >  8.11
# |   |   |   |   |   |   |--- value: [0.47]
# |   |   |--- TOEFL Score >  101.50
# |   |   |   |--- GRE Score <= 319.00
# |   |   |   |   |--- TOEFL Score <= 109.50
# |   |   |   |   |   |--- GRE Score <= 304.50
# |   |   |   |   |   |   |--- University Rating <= 2.50
# |   |   |   |   |   |   |   |--- GRE Score <= 302.00
# |   |   |   |   |   |   |   |   |--- CGPA <= 7.84
# |   |   |   |   |   |   |   |   |   |--- value: [0.58]
# |   |   |   |   |   |   |   |   |--- CGPA >  7.84
# |   |   |   |   |   |   |   |   |   |--- value: [0.56]
# |   |   |   |   |   |   |   |--- GRE Score >  302.00
# |   |   |   |   |   |   |   |   |--- value: [0.54]
# |   |   |   |   |   |   |--- University Rating >  2.50
# |   |   |   |   |   |   |   |--- TOEFL Score <= 105.50
# |   |   |   |   |   |   |   |   |--- value: [0.62]
# |   |   |   |   |   |   |   |--- TOEFL Score >  105.50
# |   |   |   |   |   |   |   |   |--- value: [0.57]
# |   |   |   |   |   |--- GRE Score >  304.50
# |   |   |   |   |   |   |--- SOP <= 2.75
# |   |   |   |   |   |   |   |--- Research <= 0.50
# |   |   |   |   |   |   |   |   |--- GRE Score <= 307.50
# |   |   |   |   |   |   |   |   |   |--- CGPA <= 8.12
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.53]
# |   |   |   |   |   |   |   |   |   |--- CGPA >  8.12
# |   |   |   |   |   |   |   |   |   |   |--- SOP <= 2.25
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.61]
# |   |   |   |   |   |   |   |   |   |   |--- SOP >  2.25
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.59]
# |   |   |   |   |   |   |   |   |--- GRE Score >  307.50
# |   |   |   |   |   |   |   |   |   |--- CGPA <= 8.11
# |   |   |   |   |   |   |   |   |   |   |--- CGPA <= 7.66
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.70]
# |   |   |   |   |   |   |   |   |   |   |--- CGPA >  7.66
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- CGPA >  8.11
# |   |   |   |   |   |   |   |   |   |   |--- CGPA <= 8.13
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- CGPA >  8.13
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- Research >  0.50
# |   |   |   |   |   |   |   |   |--- CGPA <= 7.95
# |   |   |   |   |   |   |   |   |   |--- TOEFL Score <= 104.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.59]
# |   |   |   |   |   |   |   |   |   |--- TOEFL Score >  104.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.61]
# |   |   |   |   |   |   |   |   |--- CGPA >  7.95
# |   |   |   |   |   |   |   |   |   |--- University Rating <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.49]
# |   |   |   |   |   |   |   |   |   |--- University Rating >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.50]
# |   |   |   |   |   |   |--- SOP >  2.75
# |   |   |   |   |   |   |   |--- LOR  <= 3.25
# |   |   |   |   |   |   |   |   |--- CGPA <= 7.97
# |   |   |   |   |   |   |   |   |   |--- CGPA <= 7.94
# |   |   |   |   |   |   |   |   |   |   |--- University Rating <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.64]
# |   |   |   |   |   |   |   |   |   |   |--- University Rating >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.62]
# |   |   |   |   |   |   |   |   |   |--- CGPA >  7.94
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.67]
# |   |   |   |   |   |   |   |   |--- CGPA >  7.97
# |   |   |   |   |   |   |   |   |   |--- CGPA <= 8.20
# |   |   |   |   |   |   |   |   |   |   |--- LOR  <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.61]
# |   |   |   |   |   |   |   |   |   |   |--- LOR  >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.62]
# |   |   |   |   |   |   |   |   |   |--- CGPA >  8.20
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.64]
# |   |   |   |   |   |   |   |--- LOR  >  3.25
# |   |   |   |   |   |   |   |   |--- CGPA <= 8.16
# |   |   |   |   |   |   |   |   |   |--- CGPA <= 8.02
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.71]
# |   |   |   |   |   |   |   |   |   |--- CGPA >  8.02
# |   |   |   |   |   |   |   |   |   |   |--- SOP <= 4.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.66]
# |   |   |   |   |   |   |   |   |   |   |--- SOP >  4.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.64]
# |   |   |   |   |   |   |   |   |--- CGPA >  8.16
# |   |   |   |   |   |   |   |   |   |--- value: [0.73]
# |   |   |   |   |--- TOEFL Score >  109.50
# |   |   |   |   |   |--- GRE Score <= 309.00
# |   |   |   |   |   |   |--- value: [0.46]
# |   |   |   |   |   |--- GRE Score >  309.00
# |   |   |   |   |   |   |--- value: [0.58]
# |   |   |   |--- GRE Score >  319.00
# |   |   |   |   |--- GRE Score <= 329.00
# |   |   |   |   |   |--- CGPA <= 8.15
# |   |   |   |   |   |   |--- University Rating <= 3.50
# |   |   |   |   |   |   |   |--- value: [0.70]
# |   |   |   |   |   |   |--- University Rating >  3.50
# |   |   |   |   |   |   |   |--- value: [0.72]
# |   |   |   |   |   |--- CGPA >  8.15
# |   |   |   |   |   |   |--- value: [0.75]
# |   |   |   |   |--- GRE Score >  329.00
# |   |   |   |   |   |--- value: [0.78]
# |   |--- CGPA >  8.22
# |   |   |--- GRE Score <= 318.50
# |   |   |   |--- GRE Score <= 303.00
# |   |   |   |   |--- LOR  <= 3.75
# |   |   |   |   |   |--- CGPA <= 8.50
# |   |   |   |   |   |   |--- value: [0.62]
# |   |   |   |   |   |--- CGPA >  8.50
# |   |   |   |   |   |   |--- value: [0.64]
# |   |   |   |   |--- LOR  >  3.75
# |   |   |   |   |   |--- University Rating <= 2.50
# |   |   |   |   |   |   |--- value: [0.64]
# |   |   |   |   |   |--- University Rating >  2.50
# |   |   |   |   |   |   |--- value: [0.65]
# |   |   |   |--- GRE Score >  303.00
# |   |   |   |   |--- SOP <= 1.75
# |   |   |   |   |   |--- University Rating <= 3.00
# |   |   |   |   |   |   |--- value: [0.66]
# |   |   |   |   |   |--- University Rating >  3.00
# |   |   |   |   |   |   |--- value: [0.57]
# |   |   |   |   |--- SOP >  1.75
# |   |   |   |   |   |--- University Rating <= 2.50
# |   |   |   |   |   |   |--- GRE Score <= 313.00
# |   |   |   |   |   |   |   |--- Research <= 0.50
# |   |   |   |   |   |   |   |   |--- TOEFL Score <= 109.50
# |   |   |   |   |   |   |   |   |   |--- SOP <= 2.25
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.65]
# |   |   |   |   |   |   |   |   |   |--- SOP >  2.25
# |   |   |   |   |   |   |   |   |   |   |--- GRE Score <= 305.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- GRE Score >  305.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- TOEFL Score >  109.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.63]
# |   |   |   |   |   |   |   |--- Research >  0.50
# |   |   |   |   |   |   |   |   |--- University Rating <= 1.50
# |   |   |   |   |   |   |   |   |   |--- TOEFL Score <= 99.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.71]
# |   |   |   |   |   |   |   |   |   |--- TOEFL Score >  99.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.69]
# |   |   |   |   |   |   |   |   |--- University Rating >  1.50
# |   |   |   |   |   |   |   |   |   |--- CGPA <= 8.39
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.79]
# |   |   |   |   |   |   |   |   |   |--- CGPA >  8.39
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.78]
# |   |   |   |   |   |   |--- GRE Score >  313.00
# |   |   |   |   |   |   |   |--- SOP <= 3.75
# |   |   |   |   |   |   |   |   |--- TOEFL Score <= 108.50
# |   |   |   |   |   |   |   |   |   |--- Research <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- GRE Score <= 315.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- GRE Score >  315.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Research >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- SOP <= 3.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.61]
# |   |   |   |   |   |   |   |   |   |   |--- SOP >  3.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.57]
# |   |   |   |   |   |   |   |   |--- TOEFL Score >  108.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.72]
# |   |   |   |   |   |   |   |--- SOP >  3.75
# |   |   |   |   |   |   |   |   |--- TOEFL Score <= 105.00
# |   |   |   |   |   |   |   |   |   |--- value: [0.57]
# |   |   |   |   |   |   |   |   |--- TOEFL Score >  105.00
# |   |   |   |   |   |   |   |   |   |--- value: [0.62]
# |   |   |   |   |   |--- University Rating >  2.50
# |   |   |   |   |   |   |--- CGPA <= 8.26
# |   |   |   |   |   |   |   |--- value: [0.58]
# |   |   |   |   |   |   |--- CGPA >  8.26
# |   |   |   |   |   |   |   |--- University Rating <= 4.50
# |   |   |   |   |   |   |   |   |--- LOR  <= 3.25
# |   |   |   |   |   |   |   |   |   |--- CGPA <= 8.45
# |   |   |   |   |   |   |   |   |   |   |--- Research <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Research >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.59]
# |   |   |   |   |   |   |   |   |   |--- CGPA >  8.45
# |   |   |   |   |   |   |   |   |   |   |--- Research <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Research >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- LOR  >  3.25
# |   |   |   |   |   |   |   |   |   |--- CGPA <= 8.61
# |   |   |   |   |   |   |   |   |   |   |--- LOR  <= 4.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- LOR  >  4.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- CGPA >  8.61
# |   |   |   |   |   |   |   |   |   |   |--- Research <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Research >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.71]
# |   |   |   |   |   |   |   |--- University Rating >  4.50
# |   |   |   |   |   |   |   |   |--- TOEFL Score <= 105.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.68]
# |   |   |   |   |   |   |   |   |--- TOEFL Score >  105.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.61]
# |   |   |--- GRE Score >  318.50
# |   |   |   |--- CGPA <= 8.42
# |   |   |   |   |--- LOR  <= 4.25
# |   |   |   |   |   |--- value: [0.52]
# |   |   |   |   |--- LOR  >  4.25
# |   |   |   |   |   |--- value: [0.74]
# |   |   |   |--- CGPA >  8.42
# |   |   |   |   |--- CGPA <= 8.69
# |   |   |   |   |   |--- TOEFL Score <= 109.50
# |   |   |   |   |   |   |--- GRE Score <= 321.50
# |   |   |   |   |   |   |   |--- CGPA <= 8.67
# |   |   |   |   |   |   |   |   |--- GRE Score <= 320.50
# |   |   |   |   |   |   |   |   |   |--- LOR  <= 3.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.74]
# |   |   |   |   |   |   |   |   |   |--- LOR  >  3.00
# |   |   |   |   |   |   |   |   |   |   |--- LOR  <= 4.25
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.76]
# |   |   |   |   |   |   |   |   |   |   |--- LOR  >  4.25
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.77]
# |   |   |   |   |   |   |   |   |--- GRE Score >  320.50
# |   |   |   |   |   |   |   |   |   |--- Research <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.81]
# |   |   |   |   |   |   |   |   |   |--- Research >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.79]
# |   |   |   |   |   |   |   |--- CGPA >  8.67
# |   |   |   |   |   |   |   |   |--- value: [0.69]
# |   |   |   |   |   |   |--- GRE Score >  321.50
# |   |   |   |   |   |   |   |--- GRE Score <= 322.50
# |   |   |   |   |   |   |   |   |--- University Rating <= 2.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.65]
# |   |   |   |   |   |   |   |   |--- University Rating >  2.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.71]
# |   |   |   |   |   |   |   |--- GRE Score >  322.50
# |   |   |   |   |   |   |   |   |--- value: [0.78]
# |   |   |   |   |   |--- TOEFL Score >  109.50
# |   |   |   |   |   |   |--- SOP <= 3.75
# |   |   |   |   |   |   |   |--- LOR  <= 3.50
# |   |   |   |   |   |   |   |   |--- TOEFL Score <= 112.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.79]
# |   |   |   |   |   |   |   |   |--- TOEFL Score >  112.50
# |   |   |   |   |   |   |   |   |   |--- CGPA <= 8.65
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.81]
# |   |   |   |   |   |   |   |   |   |--- CGPA >  8.65
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.80]
# |   |   |   |   |   |   |   |--- LOR  >  3.50
# |   |   |   |   |   |   |   |   |--- University Rating <= 3.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.76]
# |   |   |   |   |   |   |   |   |--- University Rating >  3.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.73]
# |   |   |   |   |   |   |--- SOP >  3.75
# |   |   |   |   |   |   |   |--- value: [0.85]
# |   |   |   |   |--- CGPA >  8.69
# |   |   |   |   |   |--- GRE Score <= 322.50
# |   |   |   |   |   |   |--- LOR  <= 2.75
# |   |   |   |   |   |   |   |--- value: [0.78]
# |   |   |   |   |   |   |--- LOR  >  2.75
# |   |   |   |   |   |   |   |--- value: [0.76]
# |   |   |   |   |   |--- GRE Score >  322.50
# |   |   |   |   |   |   |--- value: [0.52]
# |--- CGPA >  8.75
# |   |--- CGPA <= 9.15
# |   |   |--- CGPA <= 8.95
# |   |   |   |--- GRE Score <= 324.50
# |   |   |   |   |--- TOEFL Score <= 103.50
# |   |   |   |   |   |--- GRE Score <= 312.50
# |   |   |   |   |   |   |--- value: [0.67]
# |   |   |   |   |   |--- GRE Score >  312.50
# |   |   |   |   |   |   |--- GRE Score <= 316.00
# |   |   |   |   |   |   |   |--- value: [0.77]
# |   |   |   |   |   |   |--- GRE Score >  316.00
# |   |   |   |   |   |   |   |--- value: [0.73]
# |   |   |   |   |--- TOEFL Score >  103.50
# |   |   |   |   |   |--- LOR  <= 1.75
# |   |   |   |   |   |   |--- value: [0.70]
# |   |   |   |   |   |--- LOR  >  1.75
# |   |   |   |   |   |   |--- GRE Score <= 319.00
# |   |   |   |   |   |   |   |--- LOR  <= 4.25
# |   |   |   |   |   |   |   |   |--- SOP <= 4.25
# |   |   |   |   |   |   |   |   |   |--- Research <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- University Rating <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.77]
# |   |   |   |   |   |   |   |   |   |   |--- University Rating >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.75]
# |   |   |   |   |   |   |   |   |   |--- Research >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- University Rating <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.81]
# |   |   |   |   |   |   |   |   |   |   |--- University Rating >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.82]
# |   |   |   |   |   |   |   |   |--- SOP >  4.25
# |   |   |   |   |   |   |   |   |   |--- value: [0.74]
# |   |   |   |   |   |   |   |--- LOR  >  4.25
# |   |   |   |   |   |   |   |   |--- TOEFL Score <= 108.00
# |   |   |   |   |   |   |   |   |   |--- value: [0.74]
# |   |   |   |   |   |   |   |   |--- TOEFL Score >  108.00
# |   |   |   |   |   |   |   |   |   |--- value: [0.69]
# |   |   |   |   |   |   |--- GRE Score >  319.00
# |   |   |   |   |   |   |   |--- TOEFL Score <= 109.50
# |   |   |   |   |   |   |   |   |--- CGPA <= 8.82
# |   |   |   |   |   |   |   |   |   |--- SOP <= 4.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.74]
# |   |   |   |   |   |   |   |   |   |--- SOP >  4.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.76]
# |   |   |   |   |   |   |   |   |--- CGPA >  8.82
# |   |   |   |   |   |   |   |   |   |--- value: [0.78]
# |   |   |   |   |   |   |   |--- TOEFL Score >  109.50
# |   |   |   |   |   |   |   |   |--- LOR  <= 4.75
# |   |   |   |   |   |   |   |   |   |--- CGPA <= 8.92
# |   |   |   |   |   |   |   |   |   |   |--- GRE Score <= 322.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.80]
# |   |   |   |   |   |   |   |   |   |   |--- GRE Score >  322.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- CGPA >  8.92
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.77]
# |   |   |   |   |   |   |   |   |--- LOR  >  4.75
# |   |   |   |   |   |   |   |   |   |--- CGPA <= 8.87
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.82]
# |   |   |   |   |   |   |   |   |   |--- CGPA >  8.87
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.81]
# |   |   |   |--- GRE Score >  324.50
# |   |   |   |   |--- Research <= 0.50
# |   |   |   |   |   |--- value: [0.55]
# |   |   |   |   |--- Research >  0.50
# |   |   |   |   |   |--- University Rating <= 4.50
# |   |   |   |   |   |   |--- LOR  <= 3.75
# |   |   |   |   |   |   |   |--- value: [0.75]
# |   |   |   |   |   |   |--- LOR  >  3.75
# |   |   |   |   |   |   |   |--- value: [0.77]
# |   |   |   |   |   |--- University Rating >  4.50
# |   |   |   |   |   |   |--- value: [0.71]
# |   |   |--- CGPA >  8.95
# |   |   |   |--- University Rating <= 4.50
# |   |   |   |   |--- GRE Score <= 311.00
# |   |   |   |   |   |--- value: [0.66]
# |   |   |   |   |--- GRE Score >  311.00
# |   |   |   |   |   |--- TOEFL Score <= 100.00
# |   |   |   |   |   |   |--- value: [0.70]
# |   |   |   |   |   |--- TOEFL Score >  100.00
# |   |   |   |   |   |   |--- CGPA <= 8.99
# |   |   |   |   |   |   |   |--- LOR  <= 3.75
# |   |   |   |   |   |   |   |   |--- value: [0.80]
# |   |   |   |   |   |   |   |--- LOR  >  3.75
# |   |   |   |   |   |   |   |   |--- TOEFL Score <= 109.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.84]
# |   |   |   |   |   |   |   |   |--- TOEFL Score >  109.50
# |   |   |   |   |   |   |   |   |   |--- University Rating <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.86]
# |   |   |   |   |   |   |   |   |   |--- University Rating >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.87]
# |   |   |   |   |   |   |--- CGPA >  8.99
# |   |   |   |   |   |   |   |--- LOR  <= 3.25
# |   |   |   |   |   |   |   |   |--- SOP <= 3.75
# |   |   |   |   |   |   |   |   |   |--- value: [0.76]
# |   |   |   |   |   |   |   |   |--- SOP >  3.75
# |   |   |   |   |   |   |   |   |   |--- GRE Score <= 327.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.80]
# |   |   |   |   |   |   |   |   |   |--- GRE Score >  327.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.81]
# |   |   |   |   |   |   |   |--- LOR  >  3.25
# |   |   |   |   |   |   |   |   |--- LOR  <= 4.75
# |   |   |   |   |   |   |   |   |   |--- GRE Score <= 317.00
# |   |   |   |   |   |   |   |   |   |   |--- University Rating <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.80]
# |   |   |   |   |   |   |   |   |   |   |--- University Rating >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.79]
# |   |   |   |   |   |   |   |   |   |--- GRE Score >  317.00
# |   |   |   |   |   |   |   |   |   |   |--- GRE Score <= 322.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- GRE Score >  322.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- LOR  >  4.75
# |   |   |   |   |   |   |   |   |   |--- GRE Score <= 317.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.82]
# |   |   |   |   |   |   |   |   |   |--- GRE Score >  317.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.85]
# |   |   |   |--- University Rating >  4.50
# |   |   |   |   |--- Research <= 0.50
# |   |   |   |   |   |--- value: [0.78]
# |   |   |   |   |--- Research >  0.50
# |   |   |   |   |   |--- GRE Score <= 337.00
# |   |   |   |   |   |   |--- LOR  <= 4.75
# |   |   |   |   |   |   |   |--- CGPA <= 9.11
# |   |   |   |   |   |   |   |   |--- value: [0.89]
# |   |   |   |   |   |   |   |--- CGPA >  9.11
# |   |   |   |   |   |   |   |   |--- value: [0.87]
# |   |   |   |   |   |   |--- LOR  >  4.75
# |   |   |   |   |   |   |   |--- value: [0.91]
# |   |   |   |   |   |--- GRE Score >  337.00
# |   |   |   |   |   |   |--- value: [0.95]
# |   |--- CGPA >  9.15
# |   |   |--- CGPA <= 9.25
# |   |   |   |--- GRE Score <= 329.50
# |   |   |   |   |--- University Rating <= 4.50
# |   |   |   |   |   |--- TOEFL Score <= 109.50
# |   |   |   |   |   |   |--- value: [0.84]
# |   |   |   |   |   |--- TOEFL Score >  109.50
# |   |   |   |   |   |   |--- GRE Score <= 327.50
# |   |   |   |   |   |   |   |--- LOR  <= 4.25
# |   |   |   |   |   |   |   |   |--- value: [0.86]
# |   |   |   |   |   |   |   |--- LOR  >  4.25
# |   |   |   |   |   |   |   |   |--- value: [0.85]
# |   |   |   |   |   |   |--- GRE Score >  327.50
# |   |   |   |   |   |   |   |--- value: [0.87]
# |   |   |   |   |--- University Rating >  4.50
# |   |   |   |   |   |--- CGPA <= 9.18
# |   |   |   |   |   |   |--- value: [0.87]
# |   |   |   |   |   |--- CGPA >  9.18
# |   |   |   |   |   |   |--- value: [0.88]
# |   |   |   |--- GRE Score >  329.50
# |   |   |   |   |--- LOR  <= 4.25
# |   |   |   |   |   |--- value: [0.92]
# |   |   |   |   |--- LOR  >  4.25
# |   |   |   |   |   |--- value: [0.90]
# |   |   |--- CGPA >  9.25
# |   |   |   |--- CGPA <= 9.47
# |   |   |   |   |--- TOEFL Score <= 113.50
# |   |   |   |   |   |--- SOP <= 4.25
# |   |   |   |   |   |   |--- value: [0.89]
# |   |   |   |   |   |--- SOP >  4.25
# |   |   |   |   |   |   |--- CGPA <= 9.42
# |   |   |   |   |   |   |   |--- value: [0.91]
# |   |   |   |   |   |   |--- CGPA >  9.42
# |   |   |   |   |   |   |   |--- value: [0.89]
# |   |   |   |   |--- TOEFL Score >  113.50
# |   |   |   |   |   |--- LOR  <= 4.75
# |   |   |   |   |   |   |--- University Rating <= 3.00
# |   |   |   |   |   |   |   |--- value: [0.90]
# |   |   |   |   |   |   |--- University Rating >  3.00
# |   |   |   |   |   |   |   |--- LOR  <= 3.25
# |   |   |   |   |   |   |   |   |--- value: [0.90]
# |   |   |   |   |   |   |   |--- LOR  >  3.25
# |   |   |   |   |   |   |   |   |--- LOR  <= 4.25
# |   |   |   |   |   |   |   |   |   |--- value: [0.93]
# |   |   |   |   |   |   |   |   |--- LOR  >  4.25
# |   |   |   |   |   |   |   |   |   |--- University Rating <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.91]
# |   |   |   |   |   |   |   |   |   |--- University Rating >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- TOEFL Score <= 115.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.92]
# |   |   |   |   |   |   |   |   |   |   |--- TOEFL Score >  115.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.93]
# |   |   |   |   |   |--- LOR  >  4.75
# |   |   |   |   |   |   |--- TOEFL Score <= 117.50
# |   |   |   |   |   |   |   |--- University Rating <= 4.50
# |   |   |   |   |   |   |   |   |--- value: [0.94]
# |   |   |   |   |   |   |   |--- University Rating >  4.50
# |   |   |   |   |   |   |   |   |--- CGPA <= 9.33
# |   |   |   |   |   |   |   |   |   |--- value: [0.94]
# |   |   |   |   |   |   |   |   |--- CGPA >  9.33
# |   |   |   |   |   |   |   |   |   |--- value: [0.93]
# |   |   |   |   |   |   |--- TOEFL Score >  117.50
# |   |   |   |   |   |   |   |--- value: [0.92]
# |   |   |   |--- CGPA >  9.47
# |   |   |   |   |--- Research <= 0.50
# |   |   |   |   |   |--- value: [0.89]
# |   |   |   |   |--- Research >  0.50
# |   |   |   |   |   |--- GRE Score <= 332.00
# |   |   |   |   |   |   |--- GRE Score <= 325.50
# |   |   |   |   |   |   |   |--- value: [0.92]
# |   |   |   |   |   |   |--- GRE Score >  325.50
# |   |   |   |   |   |   |   |--- CGPA <= 9.70
# |   |   |   |   |   |   |   |   |--- value: [0.93]
# |   |   |   |   |   |   |   |--- CGPA >  9.70
# |   |   |   |   |   |   |   |   |--- value: [0.94]
# |   |   |   |   |   |--- GRE Score >  332.00
# |   |   |   |   |   |   |--- CGPA <= 9.71
# |   |   |   |   |   |   |   |--- TOEFL Score <= 119.50
# |   |   |   |   |   |   |   |   |--- LOR  <= 4.25
# |   |   |   |   |   |   |   |   |   |--- value: [0.95]
# |   |   |   |   |   |   |   |   |--- LOR  >  4.25
# |   |   |   |   |   |   |   |   |   |--- value: [0.94]
# |   |   |   |   |   |   |   |--- TOEFL Score >  119.50
# |   |   |   |   |   |   |   |   |--- value: [0.96]
# |   |   |   |   |   |   |--- CGPA >  9.71
# |   |   |   |   |   |   |   |--- GRE Score <= 339.50
# |   |   |   |   |   |   |   |   |--- value: [0.96]
# |   |   |   |   |   |   |   |--- GRE Score >  339.50
# |   |   |   |   |   |   |   |   |--- University Rating <= 4.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.97]
# |   |   |   |   |   |   |   |   |--- University Rating >  4.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.97]

# %% [markdown]
# Dapat dilihat bahwa *decision tree* yang dihasilkan terlihat sangat kompleks. Hal tersebut beresiko untuk terjadi *overfitting* dan juga sulit untuk divisualisasikan. Oleh karena itu, akan perubahan *hyperparameter* pada model decision tree bisa membuat model yang dihasilkan tidak terlalu kompleks.

# %%
# Membangun model tree
dt_md4 = DecisionTreeRegressor(max_depth=4)
dt_md4.fit(X_train_admission, y_train_admission)

# Melakukan visualisasi pada decision tree yang sudah dibangun sebelumnya
print(tree.export_text(dt_md4, feature_names=pd.Series(X_train_admission.columns).array))
# Out:
# |--- CGPA <= 8.75
# |   |--- CGPA <= 8.22
# |   |   |--- TOEFL Score <= 101.50
# |   |   |   |--- CGPA <= 7.66
# |   |   |   |   |--- value: [0.48]
# |   |   |   |--- CGPA >  7.66
# |   |   |   |   |--- value: [0.56]
# |   |   |--- TOEFL Score >  101.50
# |   |   |   |--- GRE Score <= 319.00
# |   |   |   |   |--- value: [0.61]
# |   |   |   |--- GRE Score >  319.00
# |   |   |   |   |--- value: [0.74]
# |   |--- CGPA >  8.22
# |   |   |--- GRE Score <= 318.50
# |   |   |   |--- GRE Score <= 303.00
# |   |   |   |   |--- value: [0.64]
# |   |   |   |--- GRE Score >  303.00
# |   |   |   |   |--- value: [0.69]
# |   |   |--- GRE Score >  318.50
# |   |   |   |--- CGPA <= 8.42
# |   |   |   |   |--- value: [0.63]
# |   |   |   |--- CGPA >  8.42
# |   |   |   |   |--- value: [0.75]
# |--- CGPA >  8.75
# |   |--- CGPA <= 9.15
# |   |   |--- CGPA <= 8.95
# |   |   |   |--- GRE Score <= 324.50
# |   |   |   |   |--- value: [0.77]
# |   |   |   |--- GRE Score >  324.50
# |   |   |   |   |--- value: [0.70]
# |   |   |--- CGPA >  8.95
# |   |   |   |--- University Rating <= 4.50
# |   |   |   |   |--- value: [0.80]
# |   |   |   |--- University Rating >  4.50
# |   |   |   |   |--- value: [0.88]
# |   |--- CGPA >  9.15
# |   |   |--- CGPA <= 9.25
# |   |   |   |--- GRE Score <= 329.50
# |   |   |   |   |--- value: [0.86]
# |   |   |   |--- GRE Score >  329.50
# |   |   |   |   |--- value: [0.91]
# |   |   |--- CGPA >  9.25
# |   |   |   |--- CGPA <= 9.47
# |   |   |   |   |--- value: [0.92]
# |   |   |   |--- CGPA >  9.47
# |   |   |   |   |--- value: [0.95]

# %% [markdown]
# Pada model decision tree di atas, dilakukan pembatasan pada kedalaman maksimal dengan mengatur nilai dari `max_depth`. Perubahan *hyperparameter* ini dilakukan untuk mendapatkan model dengan jenis yang sama namun atribut yang berbeda. Untuk pemilihan *hyperparameter* apa yang tepat, biasanya memperhatikan persebaran data pada dataset yang diberikan dan dibantu oleh pengalaman dalam melakukan serangkaian kegiatan data science.
#
# Pemilihan dari *hyperparameter* biasanya disebut sebagai *Hyperparameter Tuning* dan ada metode yang dinamakan Grid Search Cross Validation yang bisa digunakan untuk memilih *hyperparameter* terbaik dari beberapa *hyperparameter* yang disediakan berdasarkan kriteria tertentu. Jika kalian tertarik terkait dengan penerapan Grid Search Cross Validation, silakan mencari dan mempraktikannya sebagai latihan mandiri.
#
# Informasi lebih lanjut dapat diakses pada dokumentasi berikut: [link text](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)

# %% [markdown]
# ### Ensemble Learning

# %% [markdown]
# *Ensemble Learning* adalah proses di mana kita menggunakan banyak model untuk mendapatkan hasil yang lebih baik dibandingkan dengan menggunakan satu model saja. Salah satu jenis *ensemble learning* adalah *bagging* (*bootstrap aggregating*).
#
# Pada metode *bagging*, setiap model akan dilatih menggunakan subhimpunan dari data *training* (tidak keseluruhan data latih digunakan dalam setiap proses *training*). Pada subhimpunan data yang satu dengan yang lainnya bisa mengandung data yang sama (tidak harus beda semua), hal inilah yang disebut dengan *bootstrap sampling*. Nantinya, setiap model yang telah dilatih akan melakukan proses prediksi terhadap data yang baru. Hasil prediksi akhir didapatkan melalui sistem *majority voting* di mana hasil akhirnya akan menggunakan hasil prediksi yang paling banyak muncul pada model-model yang telah dibuat.
#
# ![randforest.png](data:image/png;base64,...)
#
# Sumber: Lab 4 KASDD Gasal 2023

# %% [markdown]
# ### *Random Forest*

# %% [markdown]
# *Random Forest* merupakan salah satu variasi dari konsep *bagging* pada *ensemble learning* yang menggunakan Decision Tree sebagai basis modelnya. Setiap model yang dibangun berupa Decision Tree dan nantinya model tersebut dilatih dan digunakan untuk melakukan prediksi. Output dari Random Forest itu sendiri merupakan hasil prediksi yang paling banyak muncul di antara model-model Decision Tree.

# %%
# Melakukan training pada model random forest
rf_md = RandomForestRegressor()
rf_md.fit(X_train_admission, y_train_admission)

# Memprediksi data testing
predicted = rf_md.predict(X_test_admission)


# Menampilkan metrics
regression_metrics(predicted, y_test_admission)
# Out:
# MAE: 0.05094000000000002
# MSE: 0.004652513999999997
# RMSE: 0.06820933953645936
# R_squared: 0.7659893389447754

# %%
rf_red_paramless = RandomForestClassifier()
rf_red_paramless.fit(X_train_red, y_train_red)

predicted = rf_red_paramless.predict(X_test_red)

classification_metrics(predicted, y_test_red)
# Out:
# Accuracy: 0.8480620155038759
# F1 Score: 0.8317123340548825
# Recall Score: 0.8373385301959266
# Precision Score: 0.8318384804598407

# %% [markdown]
# Terlihat bahwa terdapat perubahan pada metriknya.
#
# Diharapkan untuk mempelajari kelebihan dan kekurangan dari setiap jenis model yang dipelajari agar kita bisa mengetahui pada dataset seperti apa suatu jenis model cocok untuk digunakan. Agar model yang dihasilkan lebih baik, kita juga harus bisa memilih *hyperparameter* yang sesuai dengan permasalahan yang ingin diselesaikan.
#
# Adapun beberapa *hyperparameter* yang dapat kita eksplorasi pada Random Forest:
# * `n_estimators`: Berapa banyak decision tree yang akan membentuk random forest
# * `max_depth`: Kedalaman maksimal dari masing-masing Decision Tree
# * `min_samples_split`: Jumlah sample minimal yang diperlukan untuk memecah suatu internal node pada setiap Decision Tree
#
# Informasi lebih lanjut dapat diakses pada dokumentasi berikut: [dokumentasi Random Forest](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# Hyperparameter tuning dapat digunakan untuk mendapatkan hasil evaluasi yang terbaik untuk suatu model. Misalkan kita ingin mendapatkan parameter terbaik untuk model Decision Tree, maka kita harus mencoba berbagai kombinasi hyperparameter yang diinginkan. Untuk mempermudah mencari hyperparameter yang tepat, kita dapat menggunakan modul GridSearchCV dari library Scikit-Learn. Informasi lebih lanjut mengenai GridSearchCV dapat diakses [di sini](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html)
#
# Beberapa parameter yang sering digunakan, yaitu:
# - `estimator`: model yang akan digunakan
# - `param_grid`: kombinasi berbagai hyperparameter yang akan digunakan.
# - `cv`: jumlah cross-validation yang ingin digunakan

# %%
param_grid = {'criterion': ['squared_error', 'friedman_mse', 'absolute_error'],
               'min_samples_split': [10, 20, 50],
               'max_depth' : [5, 10, 12, None]}

dt = DecisionTreeRegressor()
clf = GridSearchCV(estimator= dt,
                   param_grid=param_grid, cv= 5)

clf.fit(X_train_admission, y_train_admission)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_depth': [5, 10, 12, None],
#                          'min_samples_split': [10, 20, 50]})

# %%
clf.best_params_
# Out:
# {'criterion': 'squared_error', 'max_depth': 5, 'min_samples_split': 20}

# %%
best_hp = DecisionTreeRegressor(**clf.best_params_)
best_hp.fit(X_train_admission, y_train_admission)
predicted = best_hp.predict(X_test_admission)
regression_metrics(predicted, y_test_admission)
# Out:
# MAE: 0.05446245334497435
# MSE: 0.005096297417658486
# RMSE: 0.07138835631710878
# R_squared: 0.743668062548485

# %% [markdown]
# Sekarang kita mendapatkan kombinasi terbaik dari berbagai kombinasi hyperparameter yang telah kita coba.

# %% [markdown]
# ## BONUS ROUND: Kaggle Competition!

# %% [markdown]
# Dalam rangka menerapkan pemahaman kalian pada materi CART dan sebagai sarana untuk **mendapatkan nilai tambahan**, kalian **diwajibkan** untuk mengikuti Kaggle Competition yang akan diadakan bersamaan dengan Lab 4 ini.
#
# **Bagaimana Cara Mengikuti?**
# *   Kalian akan menemukan tautan ke kompetisi di bagian bawah section ini. Klik tautan tersebut untuk mengakses halaman kompetisi.
# *   Kerjakan solusi Anda menggunakan notebook ini.
# *   Unggah hasil prediksi Anda ke dalam kompetisi Kaggle yang telah disediakan. Format dari submission telah dispesifikasikan pada bagian **Submission File** di laman Kaggle.
#
# **Tautan Kaggle Competition**
# *   [Kaggle Competition Regression Case](https://www.kaggle.com/competitions/lab-4-regression-case?rvi=1)
# *   [Kaggle Competition Classification Case](https://www.kaggle.com/competitions/lab-4-klasifikasi-kualitas-wine)
#
# **Nilai Bonus**
#
# Penentuan peserta yang mendapatkan nilai bonus akan ditentukan sesuai dengan peringkat dari masing-masing peserta di leaderboard, semakin tinggi peringkat kalian, semakin besar nilai bonus yang akan kalian dapatkan.

# %% [markdown]
# # Latihan Soal

# %% [markdown]
# ## SOAL 2 [10]

# %% [markdown]
# ### SOAL 2a
# [2.5] Bangun dan latih 2 model decision tree (decision tree regressor untuk admission dan decision tree classifier untuk red wine) dengan memberikan nilai pada *hyperparameter*:
# - `max_depth = 4`
# - `random_state = 2023`.

# %%
#CODE HERE
clf_red = DecisionTreeClassifier(max_depth=4, random_state=2023)
clf_red.fit(X_train_red, y_train_red)

reg_admission = DecisionTreeRegressor(max_depth=4, random_state=2023)
reg_admission.fit(X_train_admission, y_train_admission)
# Out:
# DecisionTreeRegressor(max_depth=4, random_state=2023)

# %% [markdown]
# ### SOAL 2b
# [2.5]  Visualisasikan 2 model decision tree (decision tree regressor untuk admission dan decision tree classifier untuk red wine) yang didapat pada soal 1a!

# %%
# Red Wine
print(tree.export_text(clf_red, feature_names=pd.Series(X_train_red.columns).array))
# Out:
# |--- sulphates <= 0.64
# |   |--- volatile acidity <= 0.74
# |   |   |--- alcohol <= 9.20
# |   |   |   |--- fixed acidity <= 8.41
# |   |   |   |   |--- class: 4
# |   |   |   |--- fixed acidity >  8.41
# |   |   |   |   |--- class: 3
# |   |   |--- alcohol >  9.20
# |   |   |   |--- alcohol <= 9.91
# |   |   |   |   |--- class: 5
# |   |   |   |--- alcohol >  9.91
# |   |   |   |   |--- class: 4
# |   |--- volatile acidity >  0.74
# |   |   |--- chlorides <= 0.08
# |   |   |   |--- total sulfur dioxide <= 31.84
# |   |   |   |   |--- class: 4
# |   |   |   |--- total sulfur dioxide >  31.84
# |   |   |   |   |--- class: 4
# |   |   |--- chlorides >  0.08
# |   |   |   |--- total sulfur dioxide <= 18.93
# |   |   |   |   |--- class: 3
# |   |   |   |--- total sulfur dioxide >  18.93
# |   |   |   |   |--- class: 3
# |--- sulphates >  0.64
# |   |--- alcohol <= 11.00
# |   |   |--- alcohol <= 9.90
# |   |   |   |--- total sulfur dioxide <= 49.37
# |   |   |   |   |--- class: 3
# |   |   |   |--- total sulfur dioxide >  49.37
# |   |   |   |   |--- class: 4
# |   |   |--- alcohol >  9.90
# |   |   |   |--- volatile acidity <= 0.38
# |   |   |   |   |--- class: 7
# |   |   |   |--- volatile acidity >  0.38
# |   |   |   |   |--- class: 6
# |   |--- alcohol >  11.00
# |   |   |--- chlorides <= 0.09
# |   |   |   |--- pH <= 3.24
# |   |   |   |   |--- class: 8
# |   |   |   |--- pH >  3.24
# |   |   |   |   |--- class: 8
# |   |   |--- chlorides >  0.09
# |   |   |   |--- volatile acidity <= 0.57
# |   |   |   |   |--- class: 7
# |   |   |   |--- volatile acidity >  0.57
# |   |   |   |   |--- class: 6

# %%
# Chance of Admit
print(tree.export_text(reg_admission, feature_names=pd.Series(X_train_admission.columns).array))
# Out:
# |--- CGPA <= 8.75
# |   |--- CGPA <= 8.22
# |   |   |--- TOEFL Score <= 101.50
# |   |   |   |--- CGPA <= 7.66
# |   |   |   |   |--- value: [0.48]
# |   |   |   |--- CGPA >  7.66
# |   |   |   |   |--- value: [0.56]
# |   |   |--- TOEFL Score >  101.50
# |   |   |   |--- GRE Score <= 319.00
# |   |   |   |   |--- value: [0.61]
# |   |   |   |--- GRE Score >  319.00
# |   |   |   |   |--- value: [0.74]
# |   |--- CGPA >  8.22
# |   |   |--- GRE Score <= 318.50
# |   |   |   |--- GRE Score <= 303.00
# |   |   |   |   |--- value: [0.64]
# |   |   |   |--- GRE Score >  303.00
# |   |   |   |   |--- value: [0.69]
# |   |   |--- GRE Score >  318.50
# |   |   |   |--- CGPA <= 8.42
# |   |   |   |   |--- value: [0.63]
# |   |   |   |--- CGPA >  8.42
# |   |   |   |   |--- value: [0.75]
# |--- CGPA >  8.75
# |   |--- CGPA <= 9.15
# |   |   |--- CGPA <= 8.95
# |   |   |   |--- GRE Score <= 324.50
# |   |   |   |   |--- value: [0.77]
# |   |   |   |--- GRE Score >  324.50
# |   |   |   |   |--- value: [0.70]
# |   |   |--- CGPA >  8.95
# |   |   |   |--- University Rating <= 4.50
# |   |   |   |   |--- value: [0.80]
# |   |   |   |--- University Rating >  4.50
# |   |   |   |   |--- value: [0.88]
# |   |--- CGPA >  9.15
# |   |   |--- CGPA <= 9.25
# |   |   |   |--- GRE Score <= 329.50
# |   |   |   |   |--- value: [0.86]
# |   |   |   |--- GRE Score >  329.50
# |   |   |   |   |--- value: [0.91]
# |   |   |--- CGPA >  9.25
# |   |   |   |--- CGPA <= 9.47
# |   |   |   |   |--- value: [0.92]
# |   |   |   |--- CGPA >  9.47
# |   |   |   |   |--- value: [0.95]

# %% [markdown]
# ### SOAL 2c
#
# [2.5]  Jika model decision tree regressor diberikan data aktual Chance of Admit 0.96, tentukan attribut-attribut yang menghasilkan hasil prediksi terdekat dengan data aktual tersebut. Berikan juga Mean Absolute Error dari hasil prediksi dengan data aktual `Chance of Admit` dari data X?
#
# **Catatan:** Tidak perlu dilakukan implementasi kode pada bagian ini

# %% [markdown]
# Berdasarkan pohon yang dihasilkan pada 2B, untuk mendapatkan value yang kurang lebih >= 0.95, pohon akan selalu menuju paling kanan selama memiliki atribut salah satunya adalah CGPA > 9.47, maka hasil Chance of Admitnya mendekati 0.96 dengan MAE = | 0.95 - 0.96 | = 0.01

# %% [markdown]
# ### SOAL 2d
#
# [2.5]  Untuk decision tree classifier, tentukan atribut-atribut dari suatu red wine yang paling berpotensi untuk dikategorikan sebagai kelas 4. Jika terdapat berbagai kemungkinan pasangan atribut yang paling berpotensi, cantumkanlah semua kemungkinan pasangan atribut tersebut.
#
# **Catatan:** Tidak perlu dilakukan implementasi kode pada bagian ini

# %% [markdown]
# Berdasarkan visualisasi pohon dari nomor 2B, yang terdapat 3 ranting yang menuju hasil akhir adalah class 4.
#
# 1.
# * Sulphates <= 0.64
# * Volatide acidity <= 0.74
# * alcohol <= 9.2
# * fixed acidity <= 8.41
#
# 2.
# * Sulphates <= 0.64
# * Volatide acidity > 0.74
# * chlorides <= 0.08
#
# 3.
# * Sulphates <= 0.64
# * Volatide acidity <= 0.74
# * alcohol > 9.91
#
# attribute attribute tersebutlah yang memengaruhi hasil akhir untuk mendapatkan prediksi kelas 4 pada dataset redwine

# %% [markdown]
# ## SOAL 3 [15]

# %% [markdown]
# ### SOAL 3a
#
# [5] Implementasikan 2 model Random Forest (Random Forest Regressor untuk Admission Prediction dan Random Forest Classifier untuk Red Wine) Implementasi pada soal ini akan menggunakan nilai *hyperparameter*
# - `max_depth = 3`
# - `random_state = 2023`

# %%
#CODE HERE

rf_clf = RandomForestClassifier(max_depth=3, random_state=2023)
rf_clf.fit(X_train_red, y_train_red)

rf_rgr = RandomForestRegressor(max_depth=3, random_state=2023)
rf_rgr.fit(X_train_admission, y_train_admission)
# Out:
# RandomForestRegressor(max_depth=3, random_state=2023)

# %% [markdown]
# ### SOAL 3b
#
# [5] Model Random Forest dianggap kurang dapat diinterpretasikan dibandingkan dengan Decision Tree. Apakah penyebab dari hasil tersebut?

# %% [markdown]
# Metode random forest dianggap kurang diinterpretasi karena definisi random forest itu sendiri yang terdiri dari banyak decision Tree sehingga kita tidak dapat membayangkan bagaimana bentuk dari pohon yang akan digunakan untuk mengolah data.
#
# Selain itu, dengan mengurangi overfitting pada random forest, data yang digunakan untuk membentuk tree adalah random yang dilakukan oleh mesin serta pemilihan fitur yang juga dirandom oleh mesin dan setiap pohon mungkin memiliki selected feature yang berbeda-beda. Hal ini berbeda dengan decision tree yang dibentuk dengan mementingkan gini index dan seluruh fitur yang ada.
#
# Kemudian, penyebab lainnya adalah pada saat pengambilan keputusan atau voting, random forest akan melakukan compare dengan pohon pohon lain yang ada pada forest tersebut sehingga akan sulit untuk menginterpretasi hasil prediksi dari satu pohon pada forest

# %% [markdown]
# ### SOAL 3c
#
# [5] Mekanisme voting dalam Random Forest Classifier adalah cara di mana model ini membuat prediksi akhir berdasarkan hasil dari beberapa Decision Tree yang membentuk ensemble-nya. Apakah yang membedakan mekanisme ini dengan mekanisme pengambil keputusan pada Decision Tree Classifier?

# %% [markdown]
# Seperti penjelasan pada nomor 3B, random forest sendiri adalah kumpulan decision tree yang mana data dari masing-masing pohonnya diambil secara random. Kemudian, dari sekian banyak decision tree yang dibentuk pada random forest, hasil akhirnya akan dilakukan voting dari hasil masing-masing decision tree tersebut.
#
# Selanjutnya, dengan mengedepankan reduksi overfitting, random forest melakukan random sample secara bootsraping dan mengambil fitur secara subset dari fitur fitur yang tersedia sedangkan decision tree menggunakan keseluruhan fitur dan menghitung gini index untuk melakukan split.

# %% [markdown]
# ## SOAL 4 [15]
#
# * [5] Lakukan prediksi terhadap data *testing* dari permasalahan regresi (Dataset Admission Prediction) (`X_test`) menggunakan model yang sudah dibangun pada soal 2 dan 3.
# * [5] Lakukan evaluasi pada hasil prediksi yang didapat terhadap label aktual (`y_test`). Metrik evaluasi yang ditampilkan adalah nilai MAE, MSE, RMSE, dan $R^{2}$ dari hasil prediksi yang didapat.
# * [5] Bandingkanlah hasil evaluasi dari kedua model yang sudah didapat dan tuliskan analisis singkat terkait dengan perbandingan tersebut (minimal 4 poin).

# %%
#CODE HERE

print("Decision Tree")
predicted = reg_admission.predict(X_test_admission)
regression_metrics(predicted, y_test_admission)
print()
print("Random Forest")
predicted = rf_rgr.predict(X_test_admission)
regression_metrics(predicted, y_test_admission)
# Out:
# Decision Tree
# MAE: 0.053104884175892576
# MSE: 0.004987099031448003
# RMSE: 0.07061939557549331
# R_squared: 0.7491604880507574
#
# Random Forest
# MAE: 0.04881953446233893
# MSE: 0.004414021092523637
# RMSE: 0.06643809970584376
# R_squared: 0.7779849789225435

# %% [markdown]
# Secara keseluruhan, hasil metriks evaluasi yang dihasilkan oleh random forest lebih baik.
#
# Dari segi Mean Absolute Error, mengukur rata-rata dari selisih absolut antara nilai rill dan nilai prediksi, semakin rendah semakin baik dan Random Forest memiliki hasil prediksi yang lebih dekat dengan nilai sebenarnya
#
# Dari segi Mean Square Error dan Root Mean Square Error, mengukur rata-rata kuadrat dari selisih absolut nilai prediksi dan nilai sebenarnya, random forest menghasilkan nilai yang lebih rendah yang mengindikasikan RF memprediksi lebih baik dan lebih less error dari DT
#
# Hal ini disebabkan oleh Random Forest itu sendiri yang melakukan overfitting pada pembentukan model dan menghasilkan sebuah model yang low variance lo bias sehingga model yang dibentuk semakin stabil dan sesuai dengan data aktual

# %% [markdown]
# ## SOAL 5 [15]
#
# * [5] Lakukan prediksi terhadap data *testing* dari permasalahan klasifikasi (Dataset Red Wine Prediction) (`X_test`) menggunakan model yang sudah dibangun pada soal 2 dan 3.
# * [5] Lakukan evaluasi pada hasil prediksi yang didapat terhadap label aktual (`y_test`). Metrik evaluasi yang ditampilkan adalah nilai Accuracy, Precision, Recall, dan F1-Score dari hasil prediksi yang didapat.
# * [5] Bandingkanlah hasil evaluasi yang didapat dan tuliskan analisis singkat terkait dengan perbandingan tersebut (minimal 4 poin).

# %%
#CODE HERE

print("Decision Tree")
predicted = clf_red.predict(X_test_red)
classification_metrics(predicted, y_test_red)
print()
print("Random Forest")
predicted = rf_clf.predict(X_test_red)
classification_metrics(predicted, y_test_red)
# Out:
# Decision Tree
# Accuracy: 0.5317829457364341
# F1 Score: 0.48319625990026754
# Recall Score: 0.5130067891513721
# Precision Score: 0.5030455305691744
#
# Random Forest
# Accuracy: 0.6
# F1 Score: 0.5577765891537526
# Recall Score: 0.5871427744263927
# Precision Score: 0.5920809567693396

# %% [markdown]
# Secara keseluruhan, random forest menghasilkan nilai presisi yang lebih baik dibanding dengan decision tree.
#
# Dari segi akurasi, random forest dapat memprediksi klasidikasi untuk wine lebih baik dibandingkan dengan decision tree.
#
# Dari segi presisi, semakin besar semakin mengindikasikan keakuratan prediksi, skor dari random forest juga lebih baik dibandingkan dengan decision tree.
#
# Dari segi recall score, true positive rate, nilai menebak benar / total nilai benar seharusnya, nilai dari random forest juga lebih baik dibandingkan dengan decision tree
#
# Kemudian, dari segi F1 Score yang mana skor kesatuan dari recall dan presisi, Random forest juga menghasilkan F1 score yang lebih baik.
#
# Kesimpulan ini membawa hasil sama seperti kesimpulan pada nomor 4 yaitu:
# Hal ini disebabkan oleh Random Forest itu sendiri yang melakukan overfitting pada pembentukan model dan menghasilkan sebuah model yang low variance lo bias sehingga model yang dibentuk semakin stabil dan sesuai dengan data aktual

# %% [markdown]
# ## SOAL 6 [15]
#
# Gunakan GridSearchCV untuk mencari hyperparameter yang baik untuk model Random Forest Regressor, Random Forest Classifier, Decision Tree Regressor, dan Decision Tree Classifier.

# %% [markdown]
# ### SOAL 6a
# [9]
# Proses Grid search diwajibkan melakukan tuning pada hyperparameter berikut: **criterion, max_depth, min_samples_split**.
# *Namun, kalian masih boleh mengambil hyperparameter lain.*

# %%
#CODE HERE

param_grid_reg_classifier = {
    'criterion': ['squared_error', 'poisson', 'friedman_mse', 'absolute_error'],
    'min_samples_split': [ 1, 2, 5, 10, 20, 40], 
    'max_depth': [None, 5,  10, 20, 30],
    'min_samples_leaf': [1, 2, 4, 10]
}

param_grid_rf_classifier = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 5, 10, 20, 30],
    'min_samples_split': [1, 2, 5, 10, 20, 40],
    'min_samples_leaf': [1, 2, 4, 10]
}


grid_search_rf_regressor = GridSearchCV(RandomForestRegressor(random_state=2023), param_grid_reg_classifier, cv=5)
grid_search_rf_classifier = GridSearchCV(RandomForestClassifier(random_state=2023), param_grid_rf_classifier, cv=5)
grid_search_dt_regressor = GridSearchCV(DecisionTreeRegressor(random_state=2023), param_grid_reg_classifier, cv=5)
grid_search_dt_classifier = GridSearchCV(DecisionTreeClassifier(random_state=2023), param_grid_rf_classifier, cv=5)

grid_search_rf_regressor.fit(X_train_admission, y_train_admission)
grid_search_rf_classifier.fit(X_train_red, y_train_red)
grid_search_dt_regressor.fit(X_train_admission, y_train_admission)
grid_search_dt_classifier.fit(X_train_red, y_train_red)
# Out:
# c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 400 fits failed out of a total of 2400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 400 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of RandomForestRegressor must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan 0.76089463 0.76363931 0.77057439 0.77838503 0.76603145
#         nan 0.76448167 0.76612382 0.77275369 0.77902685 0.76641654
#         nan 0.77582207 0.77582207 0.77707316 0.780662   0.76639232
#         nan 0.78049125 0.78049125 0.78049125 0.78049125 0.76677443
#         nan 0.77930239 0.77765103 0.77830986 0.77969684 0.76579203
#         nan 0.77818741 0.77826355 0.77921307 0.78009337 0.76623175
#         nan 0.78028428 0.78028428 0.78064756 0.78121329 0.76634689
#         nan 0.78042651 0.78042651 0.78042651 0.78042651 0.76677443
#         nan 0.76285179 0.76388127 0.77118451 0.77835796 0.76603145
#         nan 0.76525309 0.76646374 0.77267851 0.77902685 0.76641654
#         nan 0.77582677 0.77582677 0.77707733 0.780662   0.76639232
#         nan 0.78049125 0.78049125 0.78049125 0.78049125 0.76677443
#         nan 0.7608846  0.76363931 0.77057439 0.77838503 0.76603145
#         nan 0.76448167 0.76612382 0.77275369 0.77902685 0.76641654
#         nan 0.77582207 0.77582207 0.77707316 0.780662   0.76639232
#         nan 0.78049125 0.78049125 0.78049125 0.78049125 0.76677443
#         nan 0.76089463 0.76363931 0.77057439 0.77838503 0.76603145
#         nan 0.76448167 0.76612382 0.77275369 0.77902685 0.76641654
#         nan 0.77582207 0.77582207 0.77707316 0.780662   0.76639232
#         nan 0.78049125 0.78049125 0.78049125 0.78049125 0.76677443
#         nan 0.76012066 0.76293834 0.77027147 0.77689589 0.76477824
#         nan 0.76334116 0.76480239 0.77226309 0.7784615  0.76589419
#         nan 0.77683258 0.77683258 0.77768411 0.77954353 0.76566955
#         nan 0.77972765 0.77972765 0.77972765 0.77972765 0.76592332
#         nan 0.77793795 0.7765833  0.77740372 0.77817452 0.76468304
#         nan 0.7768385  0.77679656 0.77861656 0.77945147 0.7657537
#         nan 0.78018275 0.78018275 0.78027958 0.77957518 0.76556049
#         nan 0.77965175 0.77965175 0.77965175 0.77965175 0.76592332
#         nan 0.75911902 0.76345833 0.77072721 0.77683207 0.76477824
#         nan 0.76378583 0.76524554 0.77231488 0.7784615  0.76589419
#         nan 0.77683739 0.77683739 0.77768411 0.77954353 0.76566955
#         nan 0.77972765 0.77972765 0.77972765 0.77972765 0.76592332
#         nan 0.76011024 0.7629377  0.77027147 0.77689589 0.76477824
#         nan 0.76334116 0.76480239 0.77226309 0.7784615  0.76589419
#         nan 0.77683258 0.77683258 0.77768411 0.77954353 0.76566955
#         nan 0.77972765 0.77972765 0.77972765 0.77972765 0.76592332
#         nan 0.76012066 0.76293834 0.77027147 0.77689589 0.76477824
#         nan 0.76334116 0.76480239 0.77226309 0.7784615  0.76589419
#         nan 0.77683258 0.77683258 0.77768411 0.77954353 0.76566955
#         nan 0.77972765 0.77972765 0.77972765 0.77972765 0.76592332
#         nan 0.76060105 0.76401423 0.77053141 0.77844795 0.76603145
#         nan 0.76442948 0.76548158 0.77275678 0.77902056 0.76641654
#         nan 0.77603859 0.77603859 0.77719384 0.78067943 0.76639232
#         nan 0.78049957 0.78049957 0.78049957 0.78049957 0.76677443
#         nan 0.77917048 0.77821168 0.77864786 0.77985466 0.76579203
#         nan 0.77827477 0.77828062 0.7792592  0.78005983 0.76623175
#         nan 0.78032266 0.78032266 0.7807303  0.7812356  0.76634689
#         nan 0.78044167 0.78044167 0.78044167 0.78044167 0.76677443
#         nan 0.76324446 0.76420045 0.77108018 0.77842081 0.76603145
#         nan 0.76493656 0.76593976 0.77268019 0.77902056 0.76641654
#         nan 0.77604326 0.77604326 0.777198   0.78067943 0.76639232
#         nan 0.78049957 0.78049957 0.78049957 0.78049957 0.76677443
#         nan 0.76059631 0.76401423 0.77053141 0.77844795 0.76603145
#         nan 0.76442948 0.76548158 0.77275678 0.77902056 0.76641654
#         nan 0.77603859 0.77603859 0.77719384 0.78067943 0.76639232
#         nan 0.78049957 0.78049957 0.78049957 0.78049957 0.76677443
#         nan 0.76060105 0.76401423 0.77053141 0.77844795 0.76603145
#         nan 0.76442948 0.76548158 0.77275678 0.77902056 0.76641654
#         nan 0.77603859 0.77603859 0.77719384 0.78067943 0.76639232
#         nan 0.78049957 0.78049957 0.78049957 0.78049957 0.76677443
#         nan 0.77873244 0.77409164 0.77333377 0.77723778 0.76438514
#         nan 0.77545151 0.77659613 0.7769291  0.77841362 0.76437126
#         nan 0.77880984 0.77880984 0.77628969 0.77948929 0.76418544
#         nan 0.77608284 0.77608284 0.77608284 0.77608284 0.76364387
#         nan 0.78186698 0.77955096 0.77979622 0.77811746 0.76408025
#         nan 0.78217241 0.78141587 0.78050811 0.77900761 0.76425656
#         nan 0.78021881 0.78021881 0.77871959 0.77941838 0.76415098
#         nan 0.77605585 0.77605585 0.77605585 0.77605585 0.76364387
#         nan 0.77745565 0.77481727 0.77340859 0.77731559 0.76438514
#         nan 0.77687143 0.7764535  0.77715121 0.77841871 0.76437126
#         nan 0.77874422 0.77874422 0.77627818 0.77948929 0.76418544
#         nan 0.77608284 0.77608284 0.77608284 0.77608284 0.76364387
#         nan 0.77874234 0.77431277 0.77333562 0.77723778 0.76438514
#         nan 0.77545151 0.77659613 0.7769291  0.77841362 0.76437126
#         nan 0.77880984 0.77880984 0.77628969 0.77948929 0.76418544
#         nan 0.77608284 0.77608284 0.77608284 0.77608284 0.76364387
#         nan 0.77873244 0.77409164 0.77333377 0.77723778 0.76438514
#         nan 0.77545151 0.77659613 0.7769291  0.77841362 0.76437126
#         nan 0.77880984 0.77880984 0.77628969 0.77948929 0.76418544
#         nan 0.77608284 0.77608284 0.77608284 0.77608284 0.76364387]
#   warnings.warn(
# c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 200 fits failed out of a total of 1200.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of RandomForestClassifier must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan 0.81581471 0.8123316  0.80457364 0.78441334 0.75533755
#         nan 0.80651163 0.80961015 0.79255137 0.78285994 0.75572063
#         nan 0.79371867 0.79371867 0.79177617 0.77161737 0.75262286
#         nan 0.75649959 0.75649959 0.75649959 0.75649959 0.74176714
#         nan 0.70182434 0.70298638 0.70143524 0.7006623  0.68825469
#         nan 0.70259878 0.70337322 0.70337548 0.70027395 0.68786709
#         nan 0.69911116 0.69911116 0.70182584 0.7010514  0.68786784
#         nan 0.68981034 0.68981034 0.68981034 0.68981034 0.68282908
#         nan 0.79333484 0.80069466 0.79061489 0.77898096 0.75223753
#         nan 0.79216527 0.79255137 0.78751185 0.77122902 0.74913374
#         nan 0.7848047  0.7848047  0.78053436 0.768129   0.74602995
#         nan 0.75184692 0.75184692 0.75184692 0.75184692 0.74448182
#         nan 0.81775344 0.81271995 0.80224731 0.78441334 0.75533755
#         nan 0.80728532 0.81077369 0.79293972 0.78247234 0.75572063
#         nan 0.79371867 0.79371867 0.79177617 0.77161737 0.75262286
#         nan 0.75649959 0.75649959 0.75649959 0.75649959 0.74176714
#         nan 0.81581471 0.8123316  0.80457364 0.78441334 0.75533755
#         nan 0.80651163 0.80961015 0.79255137 0.78285994 0.75572063
#         nan 0.79371867 0.79371867 0.79177617 0.77161737 0.75262286
#         nan 0.75649959 0.75649959 0.75649959 0.75649959 0.74176714
#         nan 0.81348837 0.81116806 0.80224881 0.78635358 0.75533604
#         nan 0.81000226 0.80573568 0.80224957 0.78014977 0.75572213
#         nan 0.79333634 0.79333634 0.7913961  0.78015128 0.74874389
#         nan 0.7611515  0.7611515  0.7611515  0.7611515  0.73556107
#         nan 0.69562429 0.69756002 0.69562128 0.68825544 0.6859276
#         nan 0.69484835 0.69717242 0.69484458 0.68786784 0.6859276
#         nan 0.69600813 0.69600813 0.69368029 0.68592986 0.6863152
#         nan 0.68205464 0.68205464 0.68205464 0.68205464 0.68127869
#         nan 0.80341311 0.7979845  0.79488297 0.7766629  0.75145631
#         nan 0.79526906 0.80185971 0.79682321 0.77239783 0.7522315
#         nan 0.78170543 0.78170543 0.78247686 0.77123278 0.75262211
#         nan 0.75843832 0.75843832 0.75843832 0.75843832 0.740216
#         nan 0.81658915 0.81116806 0.80224731 0.78635358 0.75533604
#         nan 0.80883947 0.80573568 0.80263716 0.78014977 0.75572213
#         nan 0.79333634 0.79333634 0.7913961  0.78015128 0.74874389
#         nan 0.7611515  0.7611515  0.7611515  0.7611515  0.73556107
#         nan 0.81348837 0.81116806 0.80224881 0.78635358 0.75533604
#         nan 0.81000226 0.80573568 0.80224957 0.78014977 0.75572213
#         nan 0.79333634 0.79333634 0.7913961  0.78015128 0.74874389
#         nan 0.7611515  0.7611515  0.7611515  0.7611515  0.73556107]
#   warnings.warn(
# c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 400 fits failed out of a total of 2400.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 400 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of DecisionTreeRegressor must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan 0.59338679 0.61668049 0.66421479 0.72901864 0.73752335
#         nan 0.60205777 0.61375755 0.63781051 0.71360316 0.71030177
#         nan 0.69178429 0.69178429 0.69759333 0.72720482 0.72661553
#         nan 0.71936433 0.71936433 0.71936433 0.71936433 0.72147108
#         nan 0.70857435 0.69459478 0.70701802 0.74638361 0.73655452
#         nan 0.69140508 0.68945657 0.68950757 0.72071805 0.70933294
#         nan 0.7235439  0.7235439  0.72196438 0.73222304 0.72661553
#         nan 0.72129694 0.72129694 0.72129694 0.72129694 0.72147108
#         nan 0.60413643 0.61522452 0.6642129  0.72901864 0.73752335
#         nan 0.60522997 0.61314933 0.63755275 0.71360316 0.71030177
#         nan 0.69178429 0.69178429 0.69759333 0.72720482 0.72661553
#         nan 0.71936433 0.71936433 0.71936433 0.71936433 0.72147108
#         nan 0.59338679 0.61668049 0.66421479 0.72901864 0.73752335
#         nan 0.60205777 0.61375755 0.63781051 0.71360316 0.71030177
#         nan 0.69178429 0.69178429 0.69759333 0.72720482 0.72661553
#         nan 0.71936433 0.71936433 0.71936433 0.71936433 0.72147108
#         nan 0.59338679 0.61668049 0.66421479 0.72901864 0.73752335
#         nan 0.60205777 0.61375755 0.63781051 0.71360316 0.71030177
#         nan 0.69178429 0.69178429 0.69759333 0.72720482 0.72661553
#         nan 0.71936433 0.71936433 0.71936433 0.71936433 0.72147108
#         nan 0.5459446  0.59687437 0.64613753 0.71325805 0.72233389
#         nan 0.58666884 0.59041425 0.62741018 0.70492329 0.69839472
#         nan 0.71897073 0.71897073 0.71736774 0.74001037 0.73022989
#         nan 0.71743267 0.71743267 0.71743267 0.71743267 0.71788772
#         nan 0.68849447 0.68292073 0.69256762 0.72708325 0.71887265
#         nan 0.67779606 0.6775082  0.68117152 0.70748362 0.69469061
#         nan 0.74516064 0.74516064 0.74265889 0.75074092 0.73027778
#         nan 0.71804914 0.71804914 0.71804914 0.71804914 0.71788772
#         nan 0.56112402 0.58696157 0.64232895 0.71325805 0.72233389
#         nan 0.5935637  0.59806494 0.63291806 0.70492329 0.69839472
#         nan 0.72028029 0.72028029 0.71859513 0.74001037 0.73022989
#         nan 0.71743267 0.71743267 0.71743267 0.71743267 0.71788772
#         nan 0.5459446  0.59687437 0.64613753 0.71325805 0.72233389
#         nan 0.58666884 0.59041425 0.62741018 0.70492329 0.69839472
#         nan 0.71897073 0.71897073 0.71736774 0.74001037 0.73022989
#         nan 0.71743267 0.71743267 0.71743267 0.71743267 0.71788772
#         nan 0.5459446  0.59687437 0.64613753 0.71325805 0.72233389
#         nan 0.58666884 0.59041425 0.62741018 0.70492329 0.69839472
#         nan 0.71897073 0.71897073 0.71736774 0.74001037 0.73022989
#         nan 0.71743267 0.71743267 0.71743267 0.71743267 0.71788772
#         nan 0.59574983 0.63038315 0.66421479 0.72901864 0.73752335
#         nan 0.60059785 0.61154306 0.63810514 0.7130656  0.71030177
#         nan 0.69178429 0.69178429 0.69725998 0.72666726 0.72661553
#         nan 0.71936433 0.71936433 0.71936433 0.71936433 0.72147108
#         nan 0.71086734 0.70222215 0.70701802 0.74638361 0.73655452
#         nan 0.69128138 0.68947457 0.6898022  0.72256783 0.70933294
#         nan 0.7235439  0.7235439  0.72225901 0.73222304 0.72661553
#         nan 0.72129694 0.72129694 0.72129694 0.72129694 0.72147108
#         nan 0.61511835 0.6258077  0.6642129  0.72901864 0.73752335
#         nan 0.59817829 0.6092815  0.63784738 0.7130656  0.71030177
#         nan 0.69178429 0.69178429 0.69725998 0.72666726 0.72661553
#         nan 0.71936433 0.71936433 0.71936433 0.71936433 0.72147108
#         nan 0.59574983 0.63038315 0.66421479 0.72901864 0.73752335
#         nan 0.60059785 0.61154306 0.63810514 0.7130656  0.71030177
#         nan 0.69178429 0.69178429 0.69725998 0.72666726 0.72661553
#         nan 0.71936433 0.71936433 0.71936433 0.71936433 0.72147108
#         nan 0.59574983 0.63038315 0.66421479 0.72901864 0.73752335
#         nan 0.60059785 0.61154306 0.63810514 0.7130656  0.71030177
#         nan 0.69178429 0.69178429 0.69725998 0.72666726 0.72661553
#         nan 0.71936433 0.71936433 0.71936433 0.71936433 0.72147108
#         nan 0.56612355 0.55647656 0.61445891 0.71054967 0.72081806
#         nan 0.62708783 0.62593237 0.67505231 0.7309054  0.72410419
#         nan 0.70426772 0.70426772 0.71351404 0.72436975 0.72410419
#         nan 0.73687475 0.73687475 0.73687475 0.73687475 0.72836284
#         nan 0.69390815 0.69220175 0.6899072  0.71622597 0.72251965
#         nan 0.73434343 0.73104293 0.72735193 0.73814561 0.72357337
#         nan 0.7324381  0.7324381  0.73109707 0.74047898 0.72357337
#         nan 0.73691553 0.73691553 0.73691553 0.73691553 0.72836284
#         nan 0.58279192 0.59665885 0.62858334 0.71054967 0.72081806
#         nan 0.63593933 0.61078682 0.67562979 0.7309054  0.72410419
#         nan 0.70426257 0.70426257 0.71351404 0.72436975 0.72410419
#         nan 0.73687475 0.73687475 0.73687475 0.73687475 0.72836284
#         nan 0.56612355 0.55647656 0.61445891 0.71054967 0.72081806
#         nan 0.62708783 0.62593237 0.67505231 0.7309054  0.72410419
#         nan 0.70426772 0.70426772 0.71351404 0.72436975 0.72410419
#         nan 0.73687475 0.73687475 0.73687475 0.73687475 0.72836284
#         nan 0.56612355 0.55647656 0.61445891 0.71054967 0.72081806
#         nan 0.62708783 0.62593237 0.67505231 0.7309054  0.72410419
#         nan 0.70426772 0.70426772 0.71351404 0.72436975 0.72410419
#         nan 0.73687475 0.73687475 0.73687475 0.73687475 0.72836284]
#   warnings.warn(
# c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 200 fits failed out of a total of 1200.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of DecisionTreeClassifier must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\YudiSabri\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [       nan 0.72857455 0.71810868 0.71771431 0.69910514 0.67700384
#         nan 0.71422594 0.71539174 0.7111229  0.69639497 0.67235493
#         nan 0.69445473 0.69445473 0.69871529 0.6843727  0.67583954
#         nan 0.67467675 0.67467675 0.67467675 0.67467675 0.67545044
#         nan 0.60955219 0.60955219 0.6091646  0.608777   0.60451118
#         nan 0.60993979 0.60993979 0.60955219 0.6091646  0.60451118
#         nan 0.60993904 0.60993904 0.60955144 0.60877625 0.60451042
#         nan 0.60955144 0.60955144 0.60955144 0.60955144 0.60489802
#         nan 0.71150899 0.70918266 0.70414089 0.68863476 0.67118687
#         nan 0.70646948 0.70375856 0.69987732 0.68786107 0.6688628
#         nan 0.68553248 0.68553248 0.68863099 0.67661474 0.67157297
#         nan 0.66847144 0.66847144 0.66847144 0.66847144 0.672735
#         nan 0.73128772 0.71810868 0.71771431 0.69910514 0.67700384
#         nan 0.71422594 0.71539174 0.7111229  0.69639497 0.67235493
#         nan 0.69445473 0.69445473 0.69871529 0.6843727  0.67583954
#         nan 0.67467675 0.67467675 0.67467675 0.67467675 0.67545044
#         nan 0.72857455 0.71810868 0.71771431 0.69910514 0.67700384
#         nan 0.71422594 0.71539174 0.7111229  0.69639497 0.67235493
#         nan 0.69445473 0.69445473 0.69871529 0.6843727  0.67583954
#         nan 0.67467675 0.67467675 0.67467675 0.67467675 0.67545044
#         nan 0.72895386 0.72584857 0.71616317 0.70608264 0.69639046
#         nan 0.72158877 0.71926093 0.71538647 0.70491985 0.69406412
#         nan 0.71926244 0.71926244 0.7099556  0.70065176 0.69328667
#         nan 0.69134643 0.69134643 0.69134643 0.69134643 0.67972003
#         nan 0.60178295 0.60178295 0.60178295 0.59868067 0.59247836
#         nan 0.60178295 0.60178295 0.60178295 0.59868067 0.59247836
#         nan 0.60178295 0.60178295 0.60178295 0.59868067 0.59247836
#         nan 0.60061865 0.60061865 0.60061865 0.60061865 0.59364115
#         nan 0.72042297 0.71421916 0.71111763 0.69794009 0.6897983
#         nan 0.71228645 0.71034319 0.71034319 0.69639046 0.6894107
#         nan 0.70801987 0.70801987 0.70258824 0.6963882  0.69018665
#         nan 0.69057048 0.69057048 0.69057048 0.69057048 0.67855648
#         nan 0.72895386 0.72584857 0.71616317 0.70608264 0.69639046
#         nan 0.72158877 0.71926093 0.71538647 0.70491985 0.69406412
#         nan 0.71926244 0.71926244 0.7099556  0.70065176 0.69328667
#         nan 0.69134643 0.69134643 0.69134643 0.69134643 0.67972003
#         nan 0.72895386 0.72584857 0.71616317 0.70608264 0.69639046
#         nan 0.72158877 0.71926093 0.71538647 0.70491985 0.69406412
#         nan 0.71926244 0.71926244 0.7099556  0.70065176 0.69328667
#         nan 0.69134643 0.69134643 0.69134643 0.69134643 0.67972003]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=2023),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 5, 10, 20, 30],
#                          'min_samples_leaf': [1, 2, 4, 10],
#                          'min_samples_split': [1, 2, 5, 10, 20, 40]})

# %% [markdown]
# ### SOAL 6b
# [1]
#
# Tampilkan hyperparameter terbaik yang kalian dapatkan dari proses Grid Search untuk model Random Forest Regressor, Random Forest Classifier, Decision Tree Regressor, dan Decision Tree Classifier dari nomor 5a.

# %%
#CODE HERE

best_params_rf_regressor_adm = grid_search_rf_regressor.best_params_
best_score_rf_regressor_adm = grid_search_rf_regressor.best_score_

best_params_rf_classifier_red = grid_search_rf_classifier.best_params_
best_score_rf_classifier_red = grid_search_rf_classifier.best_score_

best_params_dt_regressor_adm = grid_search_dt_regressor.best_params_
best_score_dt_regressor_adm = grid_search_dt_regressor.best_score_

best_params_dt_classifier_red = grid_search_dt_classifier.best_params_
best_score_dt_classifier_red = grid_search_dt_classifier.best_score_

print("Best RF Adm" , best_params_rf_regressor_adm, best_score_rf_regressor_adm)
print("Best RF Wine" , best_params_rf_classifier_red, best_score_rf_classifier_red)
print("Best DT Adm" , best_params_dt_regressor_adm, best_score_dt_regressor_adm)
print("Best DT Red" , best_params_dt_classifier_red, best_score_dt_classifier_red)
# Out:
# Best RF Adm {'criterion': 'absolute_error', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2} 0.7821724097873274
# Best RF Wine {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2} 0.8177534432151727
# Best DT Adm {'criterion': 'poisson', 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 20} 0.7507409243708927
# Best DT Red {'criterion': 'gini', 'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2} 0.7312877248438323

# %% [markdown]
# ### SOAL 6c
# [2.5]
#
# Buatlah 2 model Random Forest (Random Forest Classifier dan Random Forest Regressor) dan 2 model Decision Tree (Decision Tree Classifier dan Decision Tree Regressor) berdasarkan hyperparameter yang kalian dapatkan dari **soal 5a**

# %%
#CODE HERE


best_rf_adm = RandomForestRegressor(
    criterion='absolute_error',
    max_depth=5,
    min_samples_leaf=2,
    min_samples_split=2,
    random_state=2023
)
best_rf_adm.fit(X_train_admission, y_train_admission)

best_rf_wine = RandomForestClassifier(
    criterion='gini',
    max_depth=20,
    min_samples_leaf=1,
    min_samples_split=2,
    random_state=2023
)
best_rf_wine.fit(X_train_red, y_train_red)

best_dt_adm = DecisionTreeRegressor(
    criterion='poisson',
    max_depth=5,
    min_samples_leaf=4,
    min_samples_split=20,
    random_state=2023
)
best_dt_adm.fit(X_train_admission, y_train_admission)

best_dt_wine = DecisionTreeClassifier(
    criterion='gini',
    max_depth=20,
    min_samples_leaf=1,
    min_samples_split=2,
    random_state=2023
)
best_dt_wine.fit(X_train_red, y_train_red)
# Out:
# DecisionTreeClassifier(max_depth=20, random_state=2023)

# %% [markdown]
# ### SOAL 6d
# [2.5]
#
# Lakukan 4 buah prediksi (karena terdapat 4 model) dengan X_test dari masing-masing dataset dan **munculkan** hasil evaluasi terhadap label y_test dari masing-masing dataset.
#
# **Note**: Terdapat 2 function metrics, yakni `regression_metrics` dan `classification_metrics`.

# %%
#CODE HERE

best_rf_adm_predicted = best_rf_adm.predict(X_test_admission)
print("BEST RF ADM")
regression_metrics(best_rf_adm_predicted, y_test_admission)
print()

best_rf_wine_predicted = best_rf_wine.predict(X_test_red)
print("BEST RF WINE")
classification_metrics(best_rf_wine_predicted, y_test_red)
print()

best_dt_adm_predicted = best_dt_adm.predict(X_test_admission)
print("BEST DT ADM")
regression_metrics(best_dt_adm_predicted, y_test_admission)
print()

best_df_wine_predicted = best_dt_wine.predict(X_test_red)
print("BEST DT WINE")
classification_metrics(best_df_wine_predicted, y_test_red)
print()
# Out:
# BEST RF ADM
# MAE: 0.046877857142857186
# MSE: 0.00408791260714286
# RMSE: 0.06393678602450127
# R_squared: 0.7943874792137137
#
# BEST RF WINE
# Accuracy: 0.8573643410852713
# F1 Score: 0.8406310633066031
# Recall Score: 0.8472675057791842
# Precision Score: 0.8408042724278205
#
# BEST DT ADM
# MAE: 0.05478182632736891
# MSE: 0.0051649749784264815
# RMSE: 0.07186776035488014
# R_squared: 0.7402137405636444
#
# BEST DT WINE
# Accuracy: 0.7457364341085271
# F1 Score: 0.7303520706652541
# Recall Score: 0.7337568187279945
# Precision Score: 0.7304741357804859

# %% [markdown]
# ## SOAL 7 [5]
# 1. [2] Jelaskan konsep bootstrapping dalam konteks Random Forests. Bagaimana hal ini berkontribusi pada keragaman dari berbagai decision trees yang terbentuk?
# 2. [1] Bagaimana prediksi dari seluruh Decision Tree Regressor digabungkan dalam Random Forest Regressor?
# 3. [2] Jelaskanlah bagaimana Random Forest dapat digunakan untuk masalah klasifikasi multi-kelas, seperti pada kasus prediksi kelas Red Wine pada Lab 4 ini.

# %% [markdown]
# 1. Bootsraping adalah suatu teknik pengambilan sampel pada random forest yang diambil dengan pengembalian. Hal ini digunakan untuk memberikan keragaman pada random forest itu sendiri sehingga membentuk banyak decision tree yang terdiri dari subset dari fitur-fitur yang dimiliki sehingga setiap pohon memiliki pola yang berbeda. Keragaman dapat terjadi karena with replacement tersebut sehingga terdapat kemungkinan sebuah data atau fitur tidak digunakan untuk pembentukan model ataupun ada data yang dipilih secara berulang kali.
#
# 2. Hasil prediksi dari keselurhan decision tree yang dibangun pada model random forest akan digabungkan dan dirata-ratakan untuk diambil output yang mayoritas atau dengan mengcompare nilai error atau nilai akurasi/presisi sehingga menghasilkan output yang stabil, low bias, low variance.
#
# 3. Random forest dapat digunakan untuk menentukan klasifikasi multi-kelas. Dari sekumpulan decision tree yang dibangun, hasil akhirnya akan menjadi output dari kelas yang merupakan mayoritas dari hasil prediksi yang dilakukan oleh DT DT tersebut. Sebagai gambaran, leaf dari DT merupakan tipe-tipe kelas yang akan dijadikan output. Dari DT DT tersebut, yang terdiri dari keragaman yang sudah proses sehingga tidak overfitting, sistem akan melakuan decision ke semua tree yang ada. Selanjutnya akan dicompare untuk didapatkan kelas apa yang paling sering muncul dari decision yang dilakukan.

# %% [markdown]
# ## SOAL 8 [5]
#
# 1. [2.5] Random Forest memasukkan unsur *randomness* melalui bootstrapping dan *feature selection*. Bagaimanakah hal ini dapat memengaruhi reproduksibilitas hasil, dan apa yang dapat dilakukan untuk memastikan *output* yang konsisten?
# 2. [2.5] Apakah *scaling* atau *feature normalization* diperlukan untuk Random Forest? Mengapa atau mengapa tidak?

# %% [markdown]
# 1. Karena unsur randomness dari bootsrapping dan feature selection tersebut, hal ini menyebabkan setiap pohon decision tree yang dibangun pada sebuah random forest memiliki pola atau struktur yang bebeda juga. Kemudian, untuk memastikan bahwa output yang dihasilkan adalah konsisten, dapat digunakan seed selection (random state) untuk memastikan kita mendapat hasil yabg sama. Selanjutya, kita juga dapat menggunakan metode cross validation untuk mengukur kinerja model dengan membentuk K model yang seukuran dan dicompare untuk mendapat yang paling baik dan stabil
#
# 2. Scaling atau feature normalization tidak diperlukan pada random forest. Hasil dari random forest tidak dipengaruhi oleh scalling karena random forest tidak melakukan perhitungan jarak ( perhitungan jarak sensitif terhadap nominal besar yang tidak discaliling ) dan setiap fitur yang dipilih dalam randomness RF juga tidak bergantung pada skala pada fitur sehingga tidak diperlukan scalling

# %% [markdown]
# ## Bonus Round

# %%
admss_bonus = pd.read_csv('Admission_Prediction_Test.csv')
feature = ['GRE Score','TOEFL Score','University Rating','SOP','LOR ','CGPA','Research']
filter_bonus = admss_bonus[feature]

# Predict Admission Prediction
predicted = best_rf_adm.predict(filter_bonus)
submit_adm = pd.DataFrame({
    'Id': admss_bonus["Unnamed: 0"].values,
    'Chance of Admit': predicted
})
submit_adm.to_csv("admission.csv", index=False)

# %%
red_bonus = pd.read_csv('Red_Wine_Quality_Test.csv')
input_test_red = red_bonus.drop('Id', axis=1)

# Predict Admission Prediction
predicted = best_rf_wine.predict(input_test_red)
submit_adm = pd.DataFrame({
    'Id': red_bonus["Id"].values,
    'Quality': predicted
})
submit_adm.to_csv("redwine.csv", index=False)
